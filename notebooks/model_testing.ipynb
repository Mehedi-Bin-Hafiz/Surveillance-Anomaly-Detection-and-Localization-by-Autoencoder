# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import imutils
import os
import tensorflow as tf

# Adjusted threshold for anomaly detection
ANOMALY_THRESHOLD = 1.3950 # A much smaller threshold is expected for single-frame MSE

# Ensure output folders exist
if not os.path.exists("output_frames"): # Re-added: Ensure output_frames directory exists
    os.makedirs("output_frames")
if not os.path.exists("reconstructed_frames"): # Folder for reconstructed image outputs (JPEGs)
    os.makedirs("reconstructed_frames")

frame_count_processed = 0
anomaly_count = 0

def mean_squared_loss(x1, x2):
    """
    Calculates the mean squared loss between two arrays.
    Returns the mean distance.
    This function is now used for single frames.
    """
    difference = x1.flatten() - x2.flatten()
    sq_difference = difference ** 2
    distance = np.sqrt(sq_difference.sum())
    n_samples = np.prod(x1.shape[1:])
    mean_distance = distance / n_samples
    return mean_distance

def combined_loss(y_true, y_pred):
    """
    Custom combined loss function for the Keras model.
    Assumes mean squared error is the primary component.
    """
    mse_loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
    return mse_loss

def preprocess_frame_for_new_model(frame):
    """
    Preprocess frame for the new model architecture.
    The new model expects better normalized inputs.
    """
    frame_resized = cv2.resize(frame, (232, 232), interpolation=cv2.INTER_AREA)
    gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
    gray = gray.astype(np.float32) / 255.0
    gray = (gray - 0.5) * 2
    return gray

# Load the trained Keras model (updated path for frame-by-frame model)
custom_objects = {'combined_loss': combined_loss}
try:
    model = load_model("../models/model.h5", custom_objects=custom_objects)
    print("Frame-by-frame model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Please ensure 'model.h5' is in the '../models/' directory.")
    exit()

# Open the video file for processing
video_path = "D:\\Research Dataset\\Surveillance\\Test\\testing_video.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit()

length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total frames in video: {length}")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video or issue reading frame.")
        break

    frame_count_processed += 1

    original_frame_color = imutils.resize(frame, width=700, height=600)
    processed_frame = preprocess_frame_for_new_model(frame)
    model_input_frame = np.expand_dims(np.expand_dims(processed_frame, axis=0), axis=-1)
    output = model.predict(model_input_frame)

    # --- Save Model Prediction (Individual Reconstructed Frame as Image) ---
    reconstructed_frame_2d = output[0, :, :, 0]

    reconstructed_frame_display = cv2.normalize(
        reconstructed_frame_2d, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U
    )
    reconstructed_frame_display = cv2.resize(
        reconstructed_frame_display, (original_frame_color.shape[1], original_frame_color.shape[0])
    )
    cv2.imwrite(f"reconstructed_frames/frame_{frame_count_processed:05d}_reconstructed.jpg", reconstructed_frame_display)
    # --- End Save Model Prediction (Image) ---

    loss = mean_squared_loss(model_input_frame, output)
    loss_scaled = loss * 1000
    loss_display = f"{loss_scaled:.5f}"
    print(f"Frame {frame_count_processed} Loss: {loss_display}")

    display_frame = original_frame_color.copy()

    status_text = f"Normal: {loss_display}"
    color = (0, 255, 0) # Green for normal

    if loss_scaled > ANOMALY_THRESHOLD:
        status_text = f"Abnormal: {loss_display}"
        color = (0, 0, 255) # Red for abnormal
        anomaly_count += 1 # Increment anomaly count only when abnormal

    cv2.putText(display_frame, status_text, (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
    
    # Re-added: Save the annotated frame to output_frames
    if status_text.startswith("Abnormal"):
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}_abnormal.jpg", display_frame)
    else:
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}_normal.jpg", display_frame)


    cv2.imshow("Anomaly Detection", display_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    if frame_count_processed % 100 == 0:
        print(f"Processed {frame_count_processed} frames, found {anomaly_count} anomalies so far.")

cap.release()
cv2.destroyAllWindows()

print(f"\nProcessing complete!")
print(f"Total frames processed: {frame_count_processed}")
print(f"Total anomalies detected: {anomaly_count}")
if frame_count_processed > 0:
    anomaly_rate = (anomaly_count / frame_count_processed * 100)
    print(f"Anomaly rate: {anomaly_rate:.2f}%")
else:
    print("No frames were processed, cannot calculate anomaly rate.")
# Out:
# Frame-by-frame model loaded successfully.
# Total frames in video: 200
# 1/1 [==============================] - 0s 107ms/step
# Frame 1 Loss: 1.38392
# 1/1 [==============================] - 0s 17ms/step
# Frame 2 Loss: 1.38264
# 1/1 [==============================] - 0s 17ms/step
# Frame 3 Loss: 1.38165
# 1/1 [==============================] - 0s 19ms/step
# Frame 4 Loss: 1.38130
# 1/1 [==============================] - 0s 17ms/step
# Frame 5 Loss: 1.38069
# 1/1 [==============================] - 0s 16ms/step
# Frame 6 Loss: 1.38025
# 1/1 [==============================] - 0s 16ms/step
# Frame 7 Loss: 1.38002
# 1/1 [==============================] - 0s 17ms/step
# Frame 8 Loss: 1.37835
# 1/1 [==============================] - 0s 17ms/step
# Frame 9 Loss: 1.37753
# 1/1 [==============================] - 0s 17ms/step
# Frame 10 Loss: 1.37680
# 1/1 [==============================] - 0s 17ms/step
# Frame 11 Loss: 1.37565
# 1/1 [==============================] - 0s 16ms/step
# Frame 12 Loss: 1.37188
# 1/1 [==============================] - 0s 17ms/step
# Frame 13 Loss: 1.36827
# 1/1 [==============================] - 0s 16ms/step
# Frame 14 Loss: 1.36809
# 1/1 [==============================] - 0s 17ms/step
# Frame 15 Loss: 1.36837
# 1/1 [==============================] - 0s 17ms/step
# Frame 16 Loss: 1.36864
# 1/1 [==============================] - 0s 17ms/step
# Frame 17 Loss: 1.36791
# 1/1 [==============================] - 0s 17ms/step
# Frame 18 Loss: 1.36896
# 1/1 [==============================] - 0s 16ms/step
# Frame 19 Loss: 1.36973
# 1/1 [==============================] - 0s 25ms/step
# Frame 20 Loss: 1.37179
# 1/1 [==============================] - 0s 19ms/step
# Frame 21 Loss: 1.37124
# 1/1 [==============================] - 0s 18ms/step
# Frame 22 Loss: 1.37103
# 1/1 [==============================] - 0s 18ms/step
# Frame 23 Loss: 1.37092
# 1/1 [==============================] - 0s 17ms/step
# Frame 24 Loss: 1.37111
# 1/1 [==============================] - 0s 18ms/step
# Frame 25 Loss: 1.37569
# 1/1 [==============================] - 0s 16ms/step
# Frame 26 Loss: 1.37643
# 1/1 [==============================] - 0s 16ms/step
# Frame 27 Loss: 1.37745
# 1/1 [==============================] - 0s 16ms/step
# Frame 28 Loss: 1.37779
# 1/1 [==============================] - 0s 18ms/step
# Frame 29 Loss: 1.37853
# 1/1 [==============================] - 0s 16ms/step
# Frame 30 Loss: 1.37859
# 1/1 [==============================] - 0s 17ms/step
# Frame 31 Loss: 1.37743
# 1/1 [==============================] - 0s 16ms/step
# Frame 32 Loss: 1.37745
# 1/1 [==============================] - 0s 17ms/step
# Frame 33 Loss: 1.37735
# 1/1 [==============================] - 0s 20ms/step
# Frame 34 Loss: 1.37799
# 1/1 [==============================] - 0s 17ms/step
# Frame 35 Loss: 1.37710
# 1/1 [==============================] - 0s 17ms/step
# Frame 36 Loss: 1.37722
# 1/1 [==============================] - 0s 16ms/step
# Frame 37 Loss: 1.37808
# 1/1 [==============================] - 0s 17ms/step
# Frame 38 Loss: 1.37646
# 1/1 [==============================] - 0s 18ms/step
# Frame 39 Loss: 1.37442
# 1/1 [==============================] - 0s 17ms/step
# Frame 40 Loss: 1.37304
# 1/1 [==============================] - 0s 17ms/step
# Frame 41 Loss: 1.37230
# 1/1 [==============================] - 0s 16ms/step
# Frame 42 Loss: 1.37304
# 1/1 [==============================] - 0s 17ms/step
# Frame 43 Loss: 1.37360
# 1/1 [==============================] - 0s 16ms/step
# Frame 44 Loss: 1.37482
# 1/1 [==============================] - 0s 16ms/step
# Frame 45 Loss: 1.37628
# 1/1 [==============================] - 0s 15ms/step
# Frame 46 Loss: 1.37696
# 1/1 [==============================] - 0s 15ms/step
# Frame 47 Loss: 1.37770
# 1/1 [==============================] - 0s 17ms/step
# Frame 48 Loss: 1.37756
# 1/1 [==============================] - 0s 16ms/step
# Frame 49 Loss: 1.37814
# 1/1 [==============================] - 0s 16ms/step
# Frame 50 Loss: 1.37735
# 1/1 [==============================] - 0s 16ms/step
# Frame 51 Loss: 1.37916
# 1/1 [==============================] - 0s 17ms/step
# Frame 52 Loss: 1.37932
# 1/1 [==============================] - 0s 16ms/step
# Frame 53 Loss: 1.38087
# 1/1 [==============================] - 0s 16ms/step
# Frame 54 Loss: 1.38133
# 1/1 [==============================] - 0s 16ms/step
# Frame 55 Loss: 1.38336
# 1/1 [==============================] - 0s 15ms/step
# Frame 56 Loss: 1.38453
# 1/1 [==============================] - 0s 16ms/step
# Frame 57 Loss: 1.38558
# 1/1 [==============================] - 0s 16ms/step
# Frame 58 Loss: 1.38611
# 1/1 [==============================] - 0s 15ms/step
# Frame 59 Loss: 1.38644
# 1/1 [==============================] - 0s 15ms/step
# Frame 60 Loss: 1.38647
# 1/1 [==============================] - 0s 17ms/step
# Frame 61 Loss: 1.38500
# 1/1 [==============================] - 0s 15ms/step
# Frame 62 Loss: 1.38530
# 1/1 [==============================] - 0s 20ms/step
# Frame 63 Loss: 1.38492
# 1/1 [==============================] - 0s 19ms/step
# Frame 64 Loss: 1.38490
# 1/1 [==============================] - 0s 17ms/step
# Frame 65 Loss: 1.38471
# 1/1 [==============================] - 0s 17ms/step
# Frame 66 Loss: 1.38439
# 1/1 [==============================] - 0s 15ms/step
# Frame 67 Loss: 1.38556
# 1/1 [==============================] - 0s 17ms/step
# Frame 68 Loss: 1.38672
# 1/1 [==============================] - 0s 16ms/step
# Frame 69 Loss: 1.38801
# 1/1 [==============================] - 0s 16ms/step
# Frame 70 Loss: 1.38871
# 1/1 [==============================] - 0s 16ms/step
# Frame 71 Loss: 1.39060
# 1/1 [==============================] - 0s 16ms/step
# Frame 72 Loss: 1.38971
# 1/1 [==============================] - 0s 16ms/step
# Frame 73 Loss: 1.39676
# 1/1 [==============================] - 0s 16ms/step
# Frame 74 Loss: 1.39687
# 1/1 [==============================] - 0s 17ms/step
# Frame 75 Loss: 1.39694
# 1/1 [==============================] - 0s 16ms/step
# Frame 76 Loss: 1.39773
# 1/1 [==============================] - 0s 16ms/step
# Frame 77 Loss: 1.39849
# 1/1 [==============================] - 0s 16ms/step
# Frame 78 Loss: 1.39963
# 1/1 [==============================] - 0s 28ms/step
# Frame 79 Loss: 1.40085
# 1/1 [==============================] - 0s 28ms/step
# Frame 80 Loss: 1.40062
# 1/1 [==============================] - 0s 27ms/step
# Frame 81 Loss: 1.40053
# 1/1 [==============================] - 0s 23ms/step
# Frame 82 Loss: 1.40195
# 1/1 [==============================] - 0s 24ms/step
# Frame 83 Loss: 1.40198
# 1/1 [==============================] - 0s 27ms/step
# Frame 84 Loss: 1.40219
# 1/1 [==============================] - 0s 22ms/step
# Frame 85 Loss: 1.40769
# 1/1 [==============================] - 0s 25ms/step
# Frame 86 Loss: 1.40664
# 1/1 [==============================] - 0s 26ms/step
# Frame 87 Loss: 1.40642
# 1/1 [==============================] - 0s 24ms/step
# Frame 88 Loss: 1.40593
# 1/1 [==============================] - 0s 25ms/step
# Frame 89 Loss: 1.40379
# 1/1 [==============================] - 0s 25ms/step
# Frame 90 Loss: 1.40320
# 1/1 [==============================] - 0s 26ms/step
# Frame 91 Loss: 1.40260
# 1/1 [==============================] - 0s 25ms/step
# Frame 92 Loss: 1.40196
# 1/1 [==============================] - 0s 28ms/step
# Frame 93 Loss: 1.40139
# 1/1 [==============================] - 0s 30ms/step
# Frame 94 Loss: 1.40214
# 1/1 [==============================] - 0s 29ms/step
# Frame 95 Loss: 1.40323
# 1/1 [==============================] - 0s 30ms/step
# Frame 96 Loss: 1.40312
# 1/1 [==============================] - 0s 32ms/step
# Frame 97 Loss: 1.40591
# 1/1 [==============================] - 0s 31ms/step
# Frame 98 Loss: 1.40286
# 1/1 [==============================] - 0s 27ms/step
# Frame 99 Loss: 1.40261
# 1/1 [==============================] - 0s 34ms/step
# Frame 100 Loss: 1.40226
# Processed 100 frames, found 28 anomalies so far.
# 1/1 [==============================] - 0s 28ms/step
# Frame 101 Loss: 1.40058
# 1/1 [==============================] - 0s 27ms/step
# Frame 102 Loss: 1.40078
# 1/1 [==============================] - 0s 29ms/step
# Frame 103 Loss: 1.40148
# 1/1 [==============================] - 0s 28ms/step
# Frame 104 Loss: 1.40143
# 1/1 [==============================] - 0s 30ms/step
# Frame 105 Loss: 1.40221
# 1/1 [==============================] - 0s 30ms/step
# Frame 106 Loss: 1.40262
# 1/1 [==============================] - 0s 31ms/step
# Frame 107 Loss: 1.40251
# 1/1 [==============================] - 0s 34ms/step
# Frame 108 Loss: 1.40241
# 1/1 [==============================] - 0s 28ms/step
# Frame 109 Loss: 1.40336
# 1/1 [==============================] - 0s 33ms/step
# Frame 110 Loss: 1.40217
# 1/1 [==============================] - 0s 28ms/step
# Frame 111 Loss: 1.40121
# 1/1 [==============================] - 0s 26ms/step
# Frame 112 Loss: 1.40050
# 1/1 [==============================] - 0s 29ms/step
# Frame 113 Loss: 1.40223
# 1/1 [==============================] - 0s 25ms/step
# Frame 114 Loss: 1.40465
# 1/1 [==============================] - 0s 25ms/step
# Frame 115 Loss: 1.40469
# 1/1 [==============================] - 0s 30ms/step
# Frame 116 Loss: 1.40548
# 1/1 [==============================] - 0s 30ms/step
# Frame 117 Loss: 1.40699
# 1/1 [==============================] - 0s 28ms/step
# Frame 118 Loss: 1.40813
# 1/1 [==============================] - 0s 28ms/step
# Frame 119 Loss: 1.40816
# 1/1 [==============================] - 0s 28ms/step
# Frame 120 Loss: 1.40753
# 1/1 [==============================] - 0s 29ms/step
# Frame 121 Loss: 1.40969
# 1/1 [==============================] - 0s 29ms/step
# Frame 122 Loss: 1.40922
# 1/1 [==============================] - 0s 29ms/step
# Frame 123 Loss: 1.40979
# 1/1 [==============================] - 0s 29ms/step
# Frame 124 Loss: 1.41126
# 1/1 [==============================] - 0s 30ms/step
# Frame 125 Loss: 1.41303
# 1/1 [==============================] - 0s 32ms/step
# Frame 126 Loss: 1.41434
# 1/1 [==============================] - 0s 31ms/step
# Frame 127 Loss: 1.41369
# 1/1 [==============================] - 0s 29ms/step
# Frame 128 Loss: 1.41442
# 1/1 [==============================] - 0s 29ms/step
# Frame 129 Loss: 1.41590
# 1/1 [==============================] - 0s 29ms/step
# Frame 130 Loss: 1.41586
# 1/1 [==============================] - 0s 30ms/step
# Frame 131 Loss: 1.41733
# 1/1 [==============================] - 0s 26ms/step
# Frame 132 Loss: 1.41810
# 1/1 [==============================] - 0s 27ms/step
# Frame 133 Loss: 1.42083
# 1/1 [==============================] - 0s 29ms/step
# Frame 134 Loss: 1.41953
# 1/1 [==============================] - 0s 37ms/step
# Frame 135 Loss: 1.42112
# 1/1 [==============================] - 0s 35ms/step
# Frame 136 Loss: 1.42045
# 1/1 [==============================] - 0s 27ms/step
# Frame 137 Loss: 1.42055
# 1/1 [==============================] - 0s 29ms/step
# Frame 138 Loss: 1.42068
# 1/1 [==============================] - 0s 30ms/step
# Frame 139 Loss: 1.42093
# 1/1 [==============================] - 0s 28ms/step
# Frame 140 Loss: 1.42228
# 1/1 [==============================] - 0s 30ms/step
# Frame 141 Loss: 1.42407
# 1/1 [==============================] - 0s 29ms/step
# Frame 142 Loss: 1.42290
# 1/1 [==============================] - 0s 26ms/step
# Frame 143 Loss: 1.42274
# 1/1 [==============================] - 0s 31ms/step
# Frame 144 Loss: 1.42351
# 1/1 [==============================] - 0s 29ms/step
# Frame 145 Loss: 1.42621
# 1/1 [==============================] - 0s 34ms/step
# Frame 146 Loss: 1.42354
# 1/1 [==============================] - 0s 32ms/step
# Frame 147 Loss: 1.42299
# 1/1 [==============================] - 0s 30ms/step
# Frame 148 Loss: 1.42334
# 1/1 [==============================] - 0s 28ms/step
# Frame 149 Loss: 1.42210
# 1/1 [==============================] - 0s 27ms/step
# Frame 150 Loss: 1.42235
# 1/1 [==============================] - 0s 29ms/step
# Frame 151 Loss: 1.41979
# 1/1 [==============================] - 0s 31ms/step
# Frame 152 Loss: 1.41823
# 1/1 [==============================] - 0s 30ms/step
# Frame 153 Loss: 1.41782
# 1/1 [==============================] - 0s 30ms/step
# Frame 154 Loss: 1.41939
# 1/1 [==============================] - 0s 31ms/step
# Frame 155 Loss: 1.42101
# 1/1 [==============================] - 0s 27ms/step
# Frame 156 Loss: 1.42566
# 1/1 [==============================] - 0s 26ms/step
# Frame 157 Loss: 1.43282
# 1/1 [==============================] - 0s 29ms/step
# Frame 158 Loss: 1.43685
# 1/1 [==============================] - 0s 29ms/step
# Frame 159 Loss: 1.43828
# 1/1 [==============================] - 0s 28ms/step
# Frame 160 Loss: 1.43996
# 1/1 [==============================] - 0s 27ms/step
# Frame 161 Loss: 1.44251
# 1/1 [==============================] - 0s 27ms/step
# Frame 162 Loss: 1.44471
# 1/1 [==============================] - 0s 26ms/step
# Frame 163 Loss: 1.44786
# 1/1 [==============================] - 0s 30ms/step
# Frame 164 Loss: 1.44335
# 1/1 [==============================] - 0s 34ms/step
# Frame 165 Loss: 1.43955
# 1/1 [==============================] - 0s 32ms/step
# Frame 166 Loss: 1.44020
# 1/1 [==============================] - 0s 28ms/step
# Frame 167 Loss: 1.43392
# 1/1 [==============================] - 0s 27ms/step
# Frame 168 Loss: 1.42626
# 1/1 [==============================] - 0s 22ms/step
# Frame 169 Loss: 1.42093
# 1/1 [==============================] - 0s 26ms/step
# Frame 170 Loss: 1.41486
# 1/1 [==============================] - 0s 21ms/step
# Frame 171 Loss: 1.40672
# 1/1 [==============================] - 0s 24ms/step
# Frame 172 Loss: 1.40230
# 1/1 [==============================] - 0s 29ms/step
# Frame 173 Loss: 1.40369
# 1/1 [==============================] - 0s 36ms/step
# Frame 174 Loss: 1.40334
# 1/1 [==============================] - 0s 36ms/step
# Frame 175 Loss: 1.40339
# 1/1 [==============================] - 0s 30ms/step
# Frame 176 Loss: 1.40474
# 1/1 [==============================] - 0s 27ms/step
# Frame 177 Loss: 1.40561
# 1/1 [==============================] - 0s 24ms/step
# Frame 178 Loss: 1.40527
# 1/1 [==============================] - 0s 30ms/step
# Frame 179 Loss: 1.40542
# 1/1 [==============================] - 0s 28ms/step
# Frame 180 Loss: 1.40471
# 1/1 [==============================] - 0s 22ms/step
# Frame 181 Loss: 1.40623
# 1/1 [==============================] - 0s 25ms/step
# Frame 182 Loss: 1.40518
# 1/1 [==============================] - 0s 27ms/step
# Frame 183 Loss: 1.40681
# 1/1 [==============================] - 0s 28ms/step
# Frame 184 Loss: 1.40653
# 1/1 [==============================] - 0s 24ms/step
# Frame 185 Loss: 1.40610
# 1/1 [==============================] - 0s 28ms/step
# Frame 186 Loss: 1.40653
# 1/1 [==============================] - 0s 27ms/step
# Frame 187 Loss: 1.40688
# 1/1 [==============================] - 0s 30ms/step
# Frame 188 Loss: 1.40693
# 1/1 [==============================] - 0s 29ms/step
# Frame 189 Loss: 1.40812
# 1/1 [==============================] - 0s 28ms/step
# Frame 190 Loss: 1.40629
# 1/1 [==============================] - 0s 25ms/step
# Frame 191 Loss: 1.40662
# 1/1 [==============================] - 0s 27ms/step
# Frame 192 Loss: 1.40727
# 1/1 [==============================] - 0s 28ms/step
# Frame 193 Loss: 1.40949
# 1/1 [==============================] - 0s 33ms/step
# Frame 194 Loss: 1.40983
# 1/1 [==============================] - 0s 28ms/step
# Frame 195 Loss: 1.40886
# 1/1 [==============================] - 0s 27ms/step
# Frame 196 Loss: 1.40969
# 1/1 [==============================] - 0s 25ms/step
# Frame 197 Loss: 1.40967
# 1/1 [==============================] - 0s 27ms/step
# Frame 198 Loss: 1.41037
# 1/1 [==============================] - 0s 27ms/step
# Frame 199 Loss: 1.41068
# 1/1 [==============================] - 0s 25ms/step
# Frame 200 Loss: 1.40947
# Processed 200 frames, found 128 anomalies so far.
# End of video or issue reading frame.
#
# Processing complete!
# Total frames processed: 200
# Total anomalies detected: 128
# Anomaly rate: 64.00%
