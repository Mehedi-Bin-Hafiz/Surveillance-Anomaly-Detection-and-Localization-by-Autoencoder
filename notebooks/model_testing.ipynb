# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import imutils
import os
import tensorflow as tf
import csv # Import the csv module

# Adjusted threshold for the new model. This threshold determines when an entire clip is considered anomalous.
# This threshold might need re-tuning for the frame-by-frame model.
ANOMALY_THRESHOLD = 1.49 # A much smaller threshold is expected for single-frame MSE

# Ensure output folders exist
if not os.path.exists("output_frames"):
    os.makedirs("output_frames")
if not os.path.exists("reconstructed_frames"): # Folder for reconstructed image outputs (JPEGs)
    os.makedirs("reconstructed_frames")
if not os.path.exists("output_predictions_csv"): # New folder for raw model predictions saved as CSV
    os.makedirs("output_predictions_csv")

frame_count_processed = 0 # Renamed from output_num to reflect frame-by-frame processing
anomaly_count = 0

# Define the main CSV log file path and header
csv_file_path = "anomaly_detection_log_frame_by_frame.csv" # New CSV name for clarity
csv_header = [
    "frame_number", # Changed from clip_number
    "overall_loss",
    "status",
    "pixel_diff_mean",
    "pixel_diff_max",
    "pixel_diff_std",
    "reconstructed_mean_pixel_value",
    "reconstructed_std_pixel_value",
    "reconstructed_min_pixel_value",
    "reconstructed_max_pixel_value"
]
csv_data = [] # List to store data rows before writing to main CSV

def mean_squared_loss(x1, x2):
    """
    Calculates the mean squared loss between two arrays.
    Returns the mean distance.
    This function is now used for single frames.
    """
    # Ensure inputs are flattened for consistent mean distance calculation
    # x1 and x2 will be (1, H, W, 1) -> flatten to (H*W)
    difference = x1.flatten() - x2.flatten()
    sq_difference = difference ** 2
    distance = np.sqrt(sq_difference.sum())
    n_samples = np.prod(x1.shape[1:]) # H*W*C
    mean_distance = distance / n_samples
    return mean_distance

def combined_loss(y_true, y_pred):
    """
    Custom combined loss function for the Keras model.
    Assumes mean squared error is the primary component.
    """
    mse_loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
    return mse_loss

def preprocess_frame_for_new_model(frame):
    """
    Preprocess frame for the new model architecture.
    The new model expects better normalized inputs.
    """
    # Resize frame to the model's expected input dimensions
    frame_resized = cv2.resize(frame, (232, 232), interpolation=cv2.INTER_AREA)
    # Convert to grayscale
    gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
    # Normalize pixel values to [0, 1]
    gray = gray.astype(np.float32) / 255.0
    # Further normalize to [-1, 1] as per model's expectation
    gray = (gray - 0.5) * 2
    return gray

# Load the trained Keras model (updated path for frame-by-frame model)
custom_objects = {'combined_loss': combined_loss}
try:
    model = load_model("../models/model_frame_by_frame.h5", custom_objects=custom_objects)
    print("Frame-by-frame model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Please ensure 'model_frame_by_frame.h5' is in the '../models/' directory.")
    exit() # Exit if model cannot be loaded

# Open the video file for processing
video_path = "D:\\Research Dataset\\Surveillance\\Test\\testing_video.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit() # Exit if video cannot be opened

length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total frames in video: {length}")

while cap.isOpened():
    ret, frame = cap.read() # Read one frame at a time
    if not ret:
        print("End of video or issue reading frame.")
        break

    frame_count_processed += 1 # Increment frame counter

    # Store the original color frame for display and saving
    original_frame_color = imutils.resize(frame, width=700, height=600)

    # Preprocess the single frame for model input
    processed_frame = preprocess_frame_for_new_model(frame)
    
    # Add batch and channel dimensions: (1, 232, 232, 1)
    model_input_frame = np.expand_dims(processed_frame, axis=0) # Add batch dim
    model_input_frame = np.expand_dims(model_input_frame, axis=-1) # Add channel dim

    # Predict with the model (output will be 1 reconstructed frame)
    output = model.predict(model_input_frame) # Output shape: (1, 232, 232, 1)

    # --- Save Model Prediction (Individual Reconstructed Frame as Image) ---
    reconstructed_frame_2d = output[0, :, :, 0] # Get the 2D reconstructed frame

    # Normalize to 0-255 and convert to 8-bit unsigned integer for saving as image
    reconstructed_frame_display = cv2.normalize(
        reconstructed_frame_2d, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U
    )
    # Resize for better viewing if desired, or keep original model output size
    reconstructed_frame_display = cv2.resize(
        reconstructed_frame_display, (original_frame_color.shape[1], original_frame_color.shape[0])
    )
    cv2.imwrite(f"reconstructed_frames/frame_{frame_count_processed:05d}_reconstructed.jpg", reconstructed_frame_display)
    # --- End Save Model Prediction (Image) ---

    # --- Save Raw Model Prediction as CSV (232x232 per frame) ---
    # Get the 2D frame (232, 232)
    frame_to_save_csv = output[0, :, :, 0]

    # Define the CSV file path for this specific frame
    per_frame_csv_path = f"output_predictions_csv/frame_{frame_count_processed:05d}_prediction.csv"

    with open(per_frame_csv_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        # Write each row of the 232x232 frame to the CSV, formatted to 5 decimal places
        for row in frame_to_save_csv:
            formatted_row = [f"{pixel:.5f}" for pixel in row] # Format each pixel value
            csv_writer.writerow(formatted_row)

    # --- End Save Raw Model Prediction as CSV ---


    # Calculate the overall reconstruction loss for the current frame
    loss = mean_squared_loss(model_input_frame, output)
    # The scaling factor for loss might need adjustment for single-frame MSE
    # A smaller scaling factor or direct loss might be more appropriate.
    # For now, let's keep it scaled by 1000 for consistency with previous display,
    # but be aware that the numerical values will be much smaller.
    loss_scaled = loss * 1000
    loss_display = f"{loss_scaled:.5f}" # Formatted to 5 decimal points
    print(f"Frame {frame_count_processed} Loss: {loss_display}")

    # Create a copy of the original color frame to draw on
    display_frame = original_frame_color.copy()

    current_status = "Normal" # Default status
    pixel_diff_mean_val = 0.0
    pixel_diff_max_val = 0.0
    pixel_diff_std_val = 0.0

    # Initialize reconstructed output statistics for the main CSV log
    reconstructed_mean_pixel_value = np.mean(output)
    reconstructed_std_pixel_value = np.std(output)
    reconstructed_min_pixel_value = np.min(output)
    reconstructed_max_pixel_value = np.max(output)


    # Check if the overall frame loss indicates an anomaly
    # The ANOMALY_THRESHOLD will likely need significant adjustment for frame-by-frame MSE
    if loss_scaled > ANOMALY_THRESHOLD: # You will need to re-tune this threshold!
        current_status = "Abnormal"
        print(f"Status: Abnormal (Score = {loss_display}) - Detecting anomalous regions...")

        # --- Anomaly Region Detection and Visualization ---
        # Extract the 2D input and reconstructed frames
        input_frame_2d = model_input_frame[0, :, :, 0]
        reconstructed_frame_2d_for_diff = output[0, :, :, 0]

        # Calculate the absolute difference (reconstruction error) pixel by pixel
        diff_frame = np.abs(input_frame_2d - reconstructed_frame_2d_for_diff)

        # Calculate statistics for CSV
        pixel_diff_mean_val = np.mean(diff_frame)
        pixel_diff_max_val = np.max(diff_frame)
        pixel_diff_std_val = np.std(diff_frame)

        # Normalize diff_frame to [0, 1] for easier thresholding
        if diff_frame.max() - diff_frame.min() == 0: # Handle flat diff_frame
            diff_frame_normalized_01 = np.zeros_like(diff_frame, dtype=np.float32)
        else:
            diff_frame_normalized_01 = cv2.normalize(diff_frame, None, 0, 1, cv2.NORM_MINMAX, cv2.CV_32F)

        # Apply a threshold to create a binary mask of high error regions.
        # This threshold (0.25) will likely need re-tuning for single-frame analysis.
        _, anomaly_mask = cv2.threshold(diff_frame_normalized_01, 0.25, 255, cv2.THRESH_BINARY)
        anomaly_mask = anomaly_mask.astype(np.uint8) # Convert to 8-bit for colormap

        # Apply a colormap to the anomaly mask.
        heatmap = cv2.applyColorMap(anomaly_mask, cv2.COLORMAP_HOT)

        # Optional: Apply a slight blur to the heatmap for smoother regions
        heatmap = cv2.GaussianBlur(heatmap, (5, 5), 0)

        # Resize the heatmap to match the dimensions of the original display frame
        heatmap_resized = cv2.resize(heatmap, (display_frame.shape[1], display_frame.shape[0]))

        # Overlay the heatmap on the original color frame.
        display_frame = cv2.addWeighted(display_frame, 0.7, heatmap_resized, 0.3, 0)
        # --- End Anomaly Region Detection and Visualization ---

        # Add text overlay for status and save the frame
        cv2.putText(display_frame, f"Abnormal: {loss_display}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2) # Red color for abnormal
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}_abnormal.jpg", display_frame)
        anomaly_count += 1
    else:
        # If the frame is normal, just add text overlay and save the frame
        print(f"Status: Normal (Score = {loss_display})")
        cv2.putText(display_frame, f"Normal: {loss_display}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2) # Green color for normal
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}_normal.jpg", display_frame)

    # Append data for the current frame to the main CSV data list, formatted to 5 decimal points
    csv_data.append([
        frame_count_processed,
        f"{float(loss_display):.5f}", # Convert to float then format for consistency
        current_status,
        f"{pixel_diff_mean_val:.5f}",
        f"{pixel_diff_max_val:.5f}",
        f"{pixel_diff_std_val:.5f}",
        f"{reconstructed_mean_pixel_value:.5f}",
        f"{reconstructed_std_pixel_value:.5f}",
        f"{reconstructed_min_pixel_value:.5f}",
        f"{reconstructed_max_pixel_value:.5f}"
    ])

    # Display the processed frame in a window
    cv2.imshow("Video Playback with Anomaly Detection", display_frame)
    cv2.waitKey(1) # Wait for 1 millisecond (allows display update)

    # Print progress every 100 frames
    if frame_count_processed % 100 == 0:
        print(f"Processed {frame_count_processed} frames, found {anomaly_count} anomalies so far.")

    # Allow exiting the loop by pressing 'q'
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release video capture and destroy all OpenCV windows
cap.release()
cv2.destroyAllWindows()

# --- Write main anomaly log data to CSV file after processing all frames ---
print(f"\nWriting overall anomaly log to {csv_file_path}...")
with open(csv_file_path, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(csv_header) # Write header
    csv_writer.writerows(csv_data) # Write all collected data rows
print("Overall anomaly log CSV file saved successfully.")
# --- End Write to CSV ---

print(f"\nProcessing complete!")
print(f"Total frames processed: {frame_count_processed}")
print(f"Total anomalies detected: {anomaly_count}")
if frame_count_processed > 0:
    anomaly_rate = (anomaly_count / frame_count_processed * 100)
    print(f"Anomaly rate: {anomaly_rate:.2f}%")
else:
    print("No frames were processed, cannot calculate anomaly rate.")
# Out:
# Frame-by-frame model loaded successfully.
# Total frames in video: 200
# 1/1 [==============================] - 0s 109ms/step
# Frame 1 Loss: 1.50866
# Status: Abnormal (Score = 1.50866) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 2 Loss: 1.50698
# Status: Abnormal (Score = 1.50698) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 3 Loss: 1.50661
# Status: Abnormal (Score = 1.50661) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 4 Loss: 1.50590
# Status: Abnormal (Score = 1.50590) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 5 Loss: 1.50511
# Status: Abnormal (Score = 1.50511) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 6 Loss: 1.50423
# Status: Abnormal (Score = 1.50423) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 7 Loss: 1.50447
# Status: Abnormal (Score = 1.50447) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 8 Loss: 1.50305
# Status: Abnormal (Score = 1.50305) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 9 Loss: 1.50216
# Status: Abnormal (Score = 1.50216) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 10 Loss: 1.50145
# Status: Abnormal (Score = 1.50145) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 11 Loss: 1.50085
# Status: Abnormal (Score = 1.50085) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 12 Loss: 1.49738
# Status: Abnormal (Score = 1.49738) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 13 Loss: 1.49427
# Status: Abnormal (Score = 1.49427) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 14 Loss: 1.49398
# Status: Abnormal (Score = 1.49398) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 15 Loss: 1.49512
# Status: Abnormal (Score = 1.49512) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 16 Loss: 1.49438
# Status: Abnormal (Score = 1.49438) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 17 Loss: 1.49346
# Status: Abnormal (Score = 1.49346) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 18 Loss: 1.49401
# Status: Abnormal (Score = 1.49401) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 19 Loss: 1.49431
# Status: Abnormal (Score = 1.49431) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 20 Loss: 1.49554
# Status: Abnormal (Score = 1.49554) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 21 Loss: 1.49412
# Status: Abnormal (Score = 1.49412) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 22 Loss: 1.49434
# Status: Abnormal (Score = 1.49434) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 23 Loss: 1.49531
# Status: Abnormal (Score = 1.49531) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 24 Loss: 1.49587
# Status: Abnormal (Score = 1.49587) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 25 Loss: 1.49876
# Status: Abnormal (Score = 1.49876) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 26 Loss: 1.49934
# Status: Abnormal (Score = 1.49934) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 27 Loss: 1.50061
# Status: Abnormal (Score = 1.50061) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 28 Loss: 1.50122
# Status: Abnormal (Score = 1.50122) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 29 Loss: 1.50154
# Status: Abnormal (Score = 1.50154) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 30 Loss: 1.50138
# Status: Abnormal (Score = 1.50138) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 31 Loss: 1.50056
# Status: Abnormal (Score = 1.50056) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 32 Loss: 1.50093
# Status: Abnormal (Score = 1.50093) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 33 Loss: 1.50186
# Status: Abnormal (Score = 1.50186) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 34 Loss: 1.50230
# Status: Abnormal (Score = 1.50230) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 35 Loss: 1.50244
# Status: Abnormal (Score = 1.50244) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 36 Loss: 1.50293
# Status: Abnormal (Score = 1.50293) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 37 Loss: 1.50398
# Status: Abnormal (Score = 1.50398) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 38 Loss: 1.50252
# Status: Abnormal (Score = 1.50252) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 39 Loss: 1.50109
# Status: Abnormal (Score = 1.50109) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 40 Loss: 1.49942
# Status: Abnormal (Score = 1.49942) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 41 Loss: 1.49935
# Status: Abnormal (Score = 1.49935) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 42 Loss: 1.49992
# Status: Abnormal (Score = 1.49992) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 43 Loss: 1.50169
# Status: Abnormal (Score = 1.50169) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 44 Loss: 1.50262
# Status: Abnormal (Score = 1.50262) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 45 Loss: 1.50386
# Status: Abnormal (Score = 1.50386) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 46 Loss: 1.50333
# Status: Abnormal (Score = 1.50333) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 47 Loss: 1.50398
# Status: Abnormal (Score = 1.50398) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 48 Loss: 1.50397
# Status: Abnormal (Score = 1.50397) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 49 Loss: 1.50634
# Status: Abnormal (Score = 1.50634) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 50 Loss: 1.50516
# Status: Abnormal (Score = 1.50516) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 51 Loss: 1.50678
# Status: Abnormal (Score = 1.50678) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 52 Loss: 1.50633
# Status: Abnormal (Score = 1.50633) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 53 Loss: 1.50795
# Status: Abnormal (Score = 1.50795) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 54 Loss: 1.50871
# Status: Abnormal (Score = 1.50871) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 55 Loss: 1.51112
# Status: Abnormal (Score = 1.51112) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 56 Loss: 1.51190
# Status: Abnormal (Score = 1.51190) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 57 Loss: 1.51314
# Status: Abnormal (Score = 1.51314) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 58 Loss: 1.51417
# Status: Abnormal (Score = 1.51417) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 21ms/step
# Frame 59 Loss: 1.51408
# Status: Abnormal (Score = 1.51408) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 60 Loss: 1.51401
# Status: Abnormal (Score = 1.51401) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 61 Loss: 1.51245
# Status: Abnormal (Score = 1.51245) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 62 Loss: 1.51231
# Status: Abnormal (Score = 1.51231) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 63 Loss: 1.51183
# Status: Abnormal (Score = 1.51183) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 64 Loss: 1.51144
# Status: Abnormal (Score = 1.51144) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 65 Loss: 1.51118
# Status: Abnormal (Score = 1.51118) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 66 Loss: 1.51055
# Status: Abnormal (Score = 1.51055) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 67 Loss: 1.51162
# Status: Abnormal (Score = 1.51162) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 68 Loss: 1.51231
# Status: Abnormal (Score = 1.51231) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 14ms/step
# Frame 69 Loss: 1.51358
# Status: Abnormal (Score = 1.51358) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 70 Loss: 1.51462
# Status: Abnormal (Score = 1.51462) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 71 Loss: 1.51686
# Status: Abnormal (Score = 1.51686) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 72 Loss: 1.51598
# Status: Abnormal (Score = 1.51598) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 73 Loss: 1.52376
# Status: Abnormal (Score = 1.52376) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 74 Loss: 1.52335
# Status: Abnormal (Score = 1.52335) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 75 Loss: 1.52329
# Status: Abnormal (Score = 1.52329) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 76 Loss: 1.52297
# Status: Abnormal (Score = 1.52297) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 77 Loss: 1.52401
# Status: Abnormal (Score = 1.52401) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 78 Loss: 1.52586
# Status: Abnormal (Score = 1.52586) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 79 Loss: 1.52745
# Status: Abnormal (Score = 1.52745) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 80 Loss: 1.52716
# Status: Abnormal (Score = 1.52716) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 81 Loss: 1.52705
# Status: Abnormal (Score = 1.52705) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 82 Loss: 1.52838
# Status: Abnormal (Score = 1.52838) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 83 Loss: 1.52917
# Status: Abnormal (Score = 1.52917) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 84 Loss: 1.52948
# Status: Abnormal (Score = 1.52948) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 85 Loss: 1.53466
# Status: Abnormal (Score = 1.53466) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 86 Loss: 1.53278
# Status: Abnormal (Score = 1.53278) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 87 Loss: 1.53217
# Status: Abnormal (Score = 1.53217) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 88 Loss: 1.53169
# Status: Abnormal (Score = 1.53169) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 89 Loss: 1.53016
# Status: Abnormal (Score = 1.53016) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 90 Loss: 1.53005
# Status: Abnormal (Score = 1.53005) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 91 Loss: 1.53010
# Status: Abnormal (Score = 1.53010) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 92 Loss: 1.52946
# Status: Abnormal (Score = 1.52946) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 24ms/step
# Frame 93 Loss: 1.52880
# Status: Abnormal (Score = 1.52880) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 94 Loss: 1.52946
# Status: Abnormal (Score = 1.52946) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 95 Loss: 1.53094
# Status: Abnormal (Score = 1.53094) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 96 Loss: 1.53124
# Status: Abnormal (Score = 1.53124) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 97 Loss: 1.53366
# Status: Abnormal (Score = 1.53366) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 98 Loss: 1.52986
# Status: Abnormal (Score = 1.52986) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 99 Loss: 1.52960
# Status: Abnormal (Score = 1.52960) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 100 Loss: 1.53048
# Status: Abnormal (Score = 1.53048) - Detecting anomalous regions...
# Processed 100 frames, found 100 anomalies so far.
# 1/1 [==============================] - 0s 16ms/step
# Frame 101 Loss: 1.53139
# Status: Abnormal (Score = 1.53139) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 102 Loss: 1.53148
# Status: Abnormal (Score = 1.53148) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 103 Loss: 1.53191
# Status: Abnormal (Score = 1.53191) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 104 Loss: 1.53194
# Status: Abnormal (Score = 1.53194) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 105 Loss: 1.53289
# Status: Abnormal (Score = 1.53289) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 106 Loss: 1.53356
# Status: Abnormal (Score = 1.53356) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 22ms/step
# Frame 107 Loss: 1.53320
# Status: Abnormal (Score = 1.53320) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 108 Loss: 1.53310
# Status: Abnormal (Score = 1.53310) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 109 Loss: 1.53344
# Status: Abnormal (Score = 1.53344) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 110 Loss: 1.53322
# Status: Abnormal (Score = 1.53322) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 111 Loss: 1.53391
# Status: Abnormal (Score = 1.53391) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 112 Loss: 1.53394
# Status: Abnormal (Score = 1.53394) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 113 Loss: 1.53631
# Status: Abnormal (Score = 1.53631) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 114 Loss: 1.53851
# Status: Abnormal (Score = 1.53851) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 115 Loss: 1.53954
# Status: Abnormal (Score = 1.53954) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 116 Loss: 1.54036
# Status: Abnormal (Score = 1.54036) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 117 Loss: 1.54132
# Status: Abnormal (Score = 1.54132) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 118 Loss: 1.54453
# Status: Abnormal (Score = 1.54453) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 119 Loss: 1.54496
# Status: Abnormal (Score = 1.54496) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 120 Loss: 1.54386
# Status: Abnormal (Score = 1.54386) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 121 Loss: 1.54608
# Status: Abnormal (Score = 1.54608) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 122 Loss: 1.54578
# Status: Abnormal (Score = 1.54578) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 123 Loss: 1.54503
# Status: Abnormal (Score = 1.54503) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 124 Loss: 1.54745
# Status: Abnormal (Score = 1.54745) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 125 Loss: 1.55119
# Status: Abnormal (Score = 1.55119) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 126 Loss: 1.55098
# Status: Abnormal (Score = 1.55098) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 127 Loss: 1.55016
# Status: Abnormal (Score = 1.55016) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 128 Loss: 1.55070
# Status: Abnormal (Score = 1.55070) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 129 Loss: 1.55338
# Status: Abnormal (Score = 1.55338) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 130 Loss: 1.55463
# Status: Abnormal (Score = 1.55463) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 131 Loss: 1.55644
# Status: Abnormal (Score = 1.55644) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 132 Loss: 1.55725
# Status: Abnormal (Score = 1.55725) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 133 Loss: 1.55696
# Status: Abnormal (Score = 1.55696) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 134 Loss: 1.55534
# Status: Abnormal (Score = 1.55534) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 135 Loss: 1.55790
# Status: Abnormal (Score = 1.55790) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 136 Loss: 1.55725
# Status: Abnormal (Score = 1.55725) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 137 Loss: 1.55707
# Status: Abnormal (Score = 1.55707) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 138 Loss: 1.55582
# Status: Abnormal (Score = 1.55582) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 139 Loss: 1.55681
# Status: Abnormal (Score = 1.55681) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 140 Loss: 1.55749
# Status: Abnormal (Score = 1.55749) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 141 Loss: 1.55834
# Status: Abnormal (Score = 1.55834) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 142 Loss: 1.55575
# Status: Abnormal (Score = 1.55575) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 143 Loss: 1.55578
# Status: Abnormal (Score = 1.55578) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 144 Loss: 1.55498
# Status: Abnormal (Score = 1.55498) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 145 Loss: 1.55407
# Status: Abnormal (Score = 1.55407) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 19ms/step
# Frame 146 Loss: 1.55247
# Status: Abnormal (Score = 1.55247) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 147 Loss: 1.55319
# Status: Abnormal (Score = 1.55319) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 148 Loss: 1.55546
# Status: Abnormal (Score = 1.55546) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 149 Loss: 1.55147
# Status: Abnormal (Score = 1.55147) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 150 Loss: 1.55296
# Status: Abnormal (Score = 1.55296) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 151 Loss: 1.55138
# Status: Abnormal (Score = 1.55138) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 152 Loss: 1.54834
# Status: Abnormal (Score = 1.54834) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 153 Loss: 1.54936
# Status: Abnormal (Score = 1.54936) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 154 Loss: 1.54863
# Status: Abnormal (Score = 1.54863) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 155 Loss: 1.54809
# Status: Abnormal (Score = 1.54809) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 156 Loss: 1.55589
# Status: Abnormal (Score = 1.55589) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 157 Loss: 1.56050
# Status: Abnormal (Score = 1.56050) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 158 Loss: 1.56281
# Status: Abnormal (Score = 1.56281) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 159 Loss: 1.56863
# Status: Abnormal (Score = 1.56863) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 160 Loss: 1.57134
# Status: Abnormal (Score = 1.57134) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 161 Loss: 1.57524
# Status: Abnormal (Score = 1.57524) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 162 Loss: 1.57778
# Status: Abnormal (Score = 1.57778) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 163 Loss: 1.57732
# Status: Abnormal (Score = 1.57732) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 164 Loss: 1.57598
# Status: Abnormal (Score = 1.57598) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 165 Loss: 1.57052
# Status: Abnormal (Score = 1.57052) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 166 Loss: 1.57082
# Status: Abnormal (Score = 1.57082) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 167 Loss: 1.56893
# Status: Abnormal (Score = 1.56893) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 168 Loss: 1.55896
# Status: Abnormal (Score = 1.55896) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 169 Loss: 1.54897
# Status: Abnormal (Score = 1.54897) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 170 Loss: 1.53671
# Status: Abnormal (Score = 1.53671) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 171 Loss: 1.52751
# Status: Abnormal (Score = 1.52751) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 172 Loss: 1.52228
# Status: Abnormal (Score = 1.52228) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 173 Loss: 1.52366
# Status: Abnormal (Score = 1.52366) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 174 Loss: 1.52287
# Status: Abnormal (Score = 1.52287) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 175 Loss: 1.52273
# Status: Abnormal (Score = 1.52273) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 176 Loss: 1.52384
# Status: Abnormal (Score = 1.52384) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 177 Loss: 1.52421
# Status: Abnormal (Score = 1.52421) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 178 Loss: 1.52376
# Status: Abnormal (Score = 1.52376) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 179 Loss: 1.52346
# Status: Abnormal (Score = 1.52346) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 180 Loss: 1.52294
# Status: Abnormal (Score = 1.52294) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 181 Loss: 1.52445
# Status: Abnormal (Score = 1.52445) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 182 Loss: 1.52324
# Status: Abnormal (Score = 1.52324) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 183 Loss: 1.52495
# Status: Abnormal (Score = 1.52495) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 184 Loss: 1.52438
# Status: Abnormal (Score = 1.52438) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 18ms/step
# Frame 185 Loss: 1.52412
# Status: Abnormal (Score = 1.52412) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 186 Loss: 1.52517
# Status: Abnormal (Score = 1.52517) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 187 Loss: 1.52580
# Status: Abnormal (Score = 1.52580) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 188 Loss: 1.52585
# Status: Abnormal (Score = 1.52585) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 189 Loss: 1.52711
# Status: Abnormal (Score = 1.52711) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 190 Loss: 1.52626
# Status: Abnormal (Score = 1.52626) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 191 Loss: 1.52669
# Status: Abnormal (Score = 1.52669) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 192 Loss: 1.52697
# Status: Abnormal (Score = 1.52697) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 193 Loss: 1.52924
# Status: Abnormal (Score = 1.52924) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 14ms/step
# Frame 194 Loss: 1.52905
# Status: Abnormal (Score = 1.52905) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 17ms/step
# Frame 195 Loss: 1.52832
# Status: Abnormal (Score = 1.52832) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 196 Loss: 1.52884
# Status: Abnormal (Score = 1.52884) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 15ms/step
# Frame 197 Loss: 1.52862
# Status: Abnormal (Score = 1.52862) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 198 Loss: 1.52953
# Status: Abnormal (Score = 1.52953) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 199 Loss: 1.52968
# Status: Abnormal (Score = 1.52968) - Detecting anomalous regions...
# 1/1 [==============================] - 0s 16ms/step
# Frame 200 Loss: 1.52873
# Status: Abnormal (Score = 1.52873) - Detecting anomalous regions...
# Processed 200 frames, found 200 anomalies so far.
# End of video or issue reading frame.
#
# Writing overall anomaly log to anomaly_detection_log_frame_by_frame.csv...
# Overall anomaly log CSV file saved successfully.
#
# Processing complete!
# Total frames processed: 200
# Total anomalies detected: 200
# Anomaly rate: 100.00%
