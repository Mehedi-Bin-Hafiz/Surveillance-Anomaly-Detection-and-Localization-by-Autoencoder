# %% [markdown]
# ## localize anomaly by detecting  generated abnormal pixels

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import imutils
import os
import tensorflow as tf

# Adjusted threshold for overall frame anomaly detection
# IMPORTANT: This threshold will likely need re-tuning after changing mean_squared_loss
ANOMALY_THRESHOLD = 0.00435 # A more typical unscaled MSE threshold for normalized data

# Threshold for identifying anomalous regions within a frame (for visualization)
# This value will likely need to be tuned based on your model's performance and data.
# It represents a pixel-wise squared error value.
ANOMALY_REGION_PIXEL_THRESHOLD = 0.200 # Example value, tune this!

model_dir = "../models/model_e50_b4.h5" # Path to the trained Keras model
video_path = "D:\\Research Dataset\\Surveillance\\Test\\testing_video.mp4"


# Ensure output folders exist
if not os.path.exists("output_frames"):
    os.makedirs("output_frames")
if not os.path.exists("reconstructed_frames"):
    os.makedirs("reconstructed_frames")
if not os.path.exists("anomaly_maps"): # New folder for error maps
    os.makedirs("anomaly_maps")
frame_count_processed = 0
anomaly_count = 0

def mean_squared_loss(x1, x2):
    """
    Calculates the true Mean Squared Error (MSE) between two arrays.
    This function is now consistent with tf.keras.losses.mean_squared_error.
    Returns the MSE.
    """
    # Ensure inputs are numpy arrays for consistent calculation,
    # as 'output' from model.predict is typically a numpy array.
    # If x1 or x2 were TensorFlow tensors, .numpy() would convert them.
    x1_np = x1.numpy() if tf.is_tensor(x1) else x1
    x2_np = x2.numpy() if tf.is_tensor(x2) else x2

    # Flatten the arrays to compute element-wise difference
    difference = x1_np.flatten() - x2_np.flatten()
    sq_difference = difference ** 2
    mse = np.mean(sq_difference) # Correct MSE calculation
    return mse

def combined_loss(y_true, y_pred):
    """
    Custom combined loss function for the Keras model.
    Assumes mean squared error is the primary component.
    This function is used during model loading/compilation.
    """
    mse_loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
    return mse_loss

def preprocess_frame_for_new_model(frame):
    """
    Preprocess frame for the new model architecture.
    The new model expects normalized inputs (e.g., in [-1, 1] range).
    """
    frame_resized = cv2.resize(frame, (232, 232), interpolation=cv2.INTER_AREA)
    gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
    gray = gray.astype(np.float32) / 255.0 # Normalize to [0, 1]
    gray = (gray - 0.5) * 2 # Scale to [-1, 1]
    return gray

# Load the trained Keras model
custom_objects = {'combined_loss': combined_loss}
try:
    model = load_model(model_dir, custom_objects=custom_objects)
    print("Frame-by-frame model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Please ensure 'model.h5' is in the '../models/' directory and the custom loss function is defined.")
    exit()

# Open the video file for processing
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit()

length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total frames in video: {length}")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video or issue reading frame.")
        break

    frame_count_processed += 1

    # Resize original frame for consistent display
    original_frame_color = imutils.resize(frame, width=700, height=600)

    # Preprocess frame for the model
    processed_frame = preprocess_frame_for_new_model(frame)
    # Add batch and channel dimensions for model input (batch_size, height, width, channels)
    model_input_frame = np.expand_dims(np.expand_dims(processed_frame, axis=0), axis=-1)

    # Get model prediction (reconstructed frame)
    output = model.predict(model_input_frame)

    # Extract the 2D reconstructed frame from the model output
    reconstructed_frame_2d = output[0, :, :, 0]

    # --- Save Model Prediction (Individual Reconstructed Frame as Image) ---
    # Normalize reconstructed frame to [0, 255] for display and saving
    # If the model output is in [-1, 1], map it back to [0, 255]
    reconstructed_frame_display = ((reconstructed_frame_2d + 1) / 2 * 255).astype(np.uint8)
    # Resize reconstructed frame to match the display size of the original frame
    reconstructed_frame_display = cv2.resize(
        reconstructed_frame_display, (original_frame_color.shape[1], original_frame_color.shape[0])
    )
    # Save the reconstructed frame
    cv2.imwrite(f"reconstructed_frames/frame_{frame_count_processed:05d}_reconstructed.jpg", reconstructed_frame_display)
    # --- End Save Model Prediction (Image) ---
    # Calculate the overall reconstruction loss (MSE) for the frame
    loss = mean_squared_loss(model_input_frame, output)
    # Removed loss_scaled as it's not needed with the corrected MSE and threshold
    loss_display = f"{loss:.5f}"
    print(f"Frame {frame_count_processed} Loss: {loss_display}")

    display_frame = original_frame_color.copy()

    status_text = f"Normal: {loss_display}"
    color = (0, 255, 0) # Green for normal

    # Check for overall frame anomaly
    if loss > ANOMALY_THRESHOLD:
        status_text = f"Anomaly: {loss_display}"
        color = (0, 0, 255) # Red for abnormal
        anomaly_count += 1 # Increment anomaly count only when overall frame is abnormal

        # --- Anomaly Localization (only if the frame is considered abnormal) ---
        # Calculate the element-wise squared difference between original and reconstructed
        # Ensure both are in the same range (e.g., [-1, 1]) for this calculation
        squared_diff_map = (processed_frame - reconstructed_frame_2d)**2

        # Normalize the squared difference map to [0, 255] for visualization
        # This makes higher differences appear brighter
        error_map_display = cv2.normalize(
            squared_diff_map, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U
        )
        # Resize the error map to the display frame's dimensions
        error_map_display_resized = cv2.resize(
            error_map_display, (original_frame_color.shape[1], original_frame_color.shape[0]),
            interpolation=cv2.INTER_LINEAR
        )
        cv2.imwrite(f"anomaly_maps/frame_{frame_count_processed:05d}_error_map.jpg", error_map_display_resized)
        
        # Create a binary mask of high error regions
        # Scale ANOMALY_REGION_PIXEL_THRESHOLD to 255 for cv2.threshold if squared_diff_map is normalized
        # Or, directly threshold the squared_diff_map values.
        # Ensure the input to threshold is 8-bit unsigned integer
        _, binary_error_mask = cv2.threshold(
            (squared_diff_map * 255).astype(np.uint8), # Scale to 0-255 for thresholding
            (ANOMALY_REGION_PIXEL_THRESHOLD * 255), # Scale threshold too
            255,
            cv2.THRESH_BINARY
        )

        # Resize the binary mask to the display frame's dimensions
        binary_error_mask_resized = cv2.resize(
            binary_error_mask, (original_frame_color.shape[1], original_frame_color.shape[0]),
            interpolation=cv2.INTER_NEAREST # Use nearest for binary masks
        )

        # Find contours in the binary mask
        contours, _ = cv2.findContours(
            binary_error_mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
        )

        # Draw bounding boxes around significant anomalous regions
        for contour in contours:
            # Filter out small noise contours
            if cv2.contourArea(contour) > 50: # Adjust this area threshold as needed
                x, y, w, h = cv2.boundingRect(contour)

                # Create a semi-transparent red overlay for the bounding box
                overlay = display_frame.copy()
                cv2.rectangle(overlay, (x, y), (x + w, y + h), (0, 0, 255), -1) # Filled red rectangle
                alpha = 0.50 # Transparency factor. 0.0 is fully transparent, 1.0 is fully opaque.
                display_frame = cv2.addWeighted(overlay, alpha, display_frame, 1 - alpha, 0)

                # Removed the line that draws the red border, leaving only the shade
                # cv2.rectangle(display_frame, (x, y), (x + w, y + h), (0, 0, 255), 2) # Red border
        # --- End Anomaly Localization ---

    # Put status text on the display frame
    cv2.putText(display_frame, status_text, (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    # Save the annotated frame to output_frames
    if status_text.startswith("Anomaly"):
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}.jpg", display_frame)
    else:
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}.jpg", display_frame)

    # Display the frame
    cv2.imshow("Anomaly Detection", display_frame)
    # Wait for a key press (1ms delay), exit on 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    # Print progress every 100 frames
    if frame_count_processed % 100 == 0:
        print(f"Processed {frame_count_processed} frames, found {anomaly_count} anomalies so far.")

# Release video capture and destroy all OpenCV windows
cap.release()
cv2.destroyAllWindows()

print(f"\nProcessing complete!")
print(f"Total frames processed: {frame_count_processed}")
print(f"Total anomalies detected: {anomaly_count}")
if frame_count_processed > 0:
    anomaly_rate = (anomaly_count / frame_count_processed * 100)
    print(f"Anomaly rate: {anomaly_rate:.2f}%")
else:
    print("No frames were processed, cannot calculate anomaly rate.")
# Out:
# Frame-by-frame model loaded successfully.
# Total frames in video: 200
# 1/1 [==============================] - 9s 9s/step
# Frame 1 Loss: 0.00413
# 1/1 [==============================] - 0s 21ms/step
# Frame 2 Loss: 0.00415
# 1/1 [==============================] - 0s 18ms/step
# Frame 3 Loss: 0.00417
# 1/1 [==============================] - 0s 18ms/step
# Frame 4 Loss: 0.00417
# 1/1 [==============================] - 0s 17ms/step
# Frame 5 Loss: 0.00419
# 1/1 [==============================] - 0s 20ms/step
# Frame 6 Loss: 0.00416
# 1/1 [==============================] - 0s 18ms/step
# Frame 7 Loss: 0.00416
# 1/1 [==============================] - 0s 21ms/step
# Frame 8 Loss: 0.00422
# 1/1 [==============================] - 0s 18ms/step
# Frame 9 Loss: 0.00432
# 1/1 [==============================] - 0s 18ms/step
# Frame 10 Loss: 0.00418
# 1/1 [==============================] - 0s 19ms/step
# Frame 11 Loss: 0.00420
# 1/1 [==============================] - 0s 18ms/step
# Frame 12 Loss: 0.00416
# 1/1 [==============================] - 0s 17ms/step
# Frame 13 Loss: 0.00424
# 1/1 [==============================] - 0s 20ms/step
# Frame 14 Loss: 0.00410
# 1/1 [==============================] - 0s 18ms/step
# Frame 15 Loss: 0.00405
# 1/1 [==============================] - 0s 20ms/step
# Frame 16 Loss: 0.00406
# 1/1 [==============================] - 0s 20ms/step
# Frame 17 Loss: 0.00417
# 1/1 [==============================] - 0s 20ms/step
# Frame 18 Loss: 0.00409
# 1/1 [==============================] - 0s 20ms/step
# Frame 19 Loss: 0.00408
# 1/1 [==============================] - 0s 22ms/step
# Frame 20 Loss: 0.00417
# 1/1 [==============================] - 0s 18ms/step
# Frame 21 Loss: 0.00407
# 1/1 [==============================] - 0s 18ms/step
# Frame 22 Loss: 0.00403
# 1/1 [==============================] - 0s 19ms/step
# Frame 23 Loss: 0.00407
# 1/1 [==============================] - 0s 17ms/step
# Frame 24 Loss: 0.00407
# 1/1 [==============================] - 0s 17ms/step
# Frame 25 Loss: 0.00408
# 1/1 [==============================] - 0s 18ms/step
# Frame 26 Loss: 0.00393
# 1/1 [==============================] - 0s 19ms/step
# Frame 27 Loss: 0.00397
# 1/1 [==============================] - 0s 18ms/step
# Frame 28 Loss: 0.00397
# 1/1 [==============================] - 0s 20ms/step
# Frame 29 Loss: 0.00394
# 1/1 [==============================] - 0s 19ms/step
# Frame 30 Loss: 0.00391
# 1/1 [==============================] - 0s 19ms/step
# Frame 31 Loss: 0.00391
# 1/1 [==============================] - 0s 17ms/step
# Frame 32 Loss: 0.00395
# 1/1 [==============================] - 0s 17ms/step
# Frame 33 Loss: 0.00397
# 1/1 [==============================] - 0s 18ms/step
# Frame 34 Loss: 0.00392
# 1/1 [==============================] - 0s 19ms/step
# Frame 35 Loss: 0.00392
# 1/1 [==============================] - 0s 18ms/step
# Frame 36 Loss: 0.00390
# 1/1 [==============================] - 0s 18ms/step
# Frame 37 Loss: 0.00393
# 1/1 [==============================] - 0s 19ms/step
# Frame 38 Loss: 0.00398
# 1/1 [==============================] - 0s 16ms/step
# Frame 39 Loss: 0.00395
# 1/1 [==============================] - 0s 18ms/step
# Frame 40 Loss: 0.00391
# 1/1 [==============================] - 0s 22ms/step
# Frame 41 Loss: 0.00397
# 1/1 [==============================] - 0s 17ms/step
# Frame 42 Loss: 0.00408
# 1/1 [==============================] - 0s 20ms/step
# Frame 43 Loss: 0.00419
# 1/1 [==============================] - 0s 20ms/step
# Frame 44 Loss: 0.00424
# 1/1 [==============================] - 0s 18ms/step
# Frame 45 Loss: 0.00422
# 1/1 [==============================] - 0s 19ms/step
# Frame 46 Loss: 0.00422
# 1/1 [==============================] - 0s 16ms/step
# Frame 47 Loss: 0.00425
# 1/1 [==============================] - 0s 17ms/step
# Frame 48 Loss: 0.00417
# 1/1 [==============================] - 0s 20ms/step
# Frame 49 Loss: 0.00428
# 1/1 [==============================] - 0s 20ms/step
# Frame 50 Loss: 0.00420
# 1/1 [==============================] - 0s 18ms/step
# Frame 51 Loss: 0.00430
# 1/1 [==============================] - 0s 20ms/step
# Frame 52 Loss: 0.00424
# 1/1 [==============================] - 0s 21ms/step
# Frame 53 Loss: 0.00442
# 1/1 [==============================] - 0s 18ms/step
# Frame 54 Loss: 0.00436
# 1/1 [==============================] - 0s 17ms/step
# Frame 55 Loss: 0.00436
# 1/1 [==============================] - 0s 21ms/step
# Frame 56 Loss: 0.00440
# 1/1 [==============================] - 0s 22ms/step
# Frame 57 Loss: 0.00434
# 1/1 [==============================] - 0s 18ms/step
# Frame 58 Loss: 0.00448
# 1/1 [==============================] - 0s 19ms/step
# Frame 59 Loss: 0.00446
# 1/1 [==============================] - 0s 19ms/step
# Frame 60 Loss: 0.00442
# 1/1 [==============================] - 0s 17ms/step
# Frame 61 Loss: 0.00439
# 1/1 [==============================] - 0s 19ms/step
# Frame 62 Loss: 0.00446
# 1/1 [==============================] - 0s 21ms/step
# Frame 63 Loss: 0.00460
# 1/1 [==============================] - 0s 21ms/step
# Frame 64 Loss: 0.00458
# 1/1 [==============================] - 0s 22ms/step
# Frame 65 Loss: 0.00446
# 1/1 [==============================] - 0s 18ms/step
# Frame 66 Loss: 0.00447
# 1/1 [==============================] - 0s 18ms/step
# Frame 67 Loss: 0.00466
# 1/1 [==============================] - 0s 18ms/step
# Frame 68 Loss: 0.00459
# 1/1 [==============================] - 0s 17ms/step
# Frame 69 Loss: 0.00467
# 1/1 [==============================] - 0s 18ms/step
# Frame 70 Loss: 0.00469
# 1/1 [==============================] - 0s 24ms/step
# Frame 71 Loss: 0.00527
# 1/1 [==============================] - 0s 20ms/step
# Frame 72 Loss: 0.00535
# 1/1 [==============================] - 0s 19ms/step
# Frame 73 Loss: 0.00532
# 1/1 [==============================] - 0s 20ms/step
# Frame 74 Loss: 0.00522
# 1/1 [==============================] - 0s 17ms/step
# Frame 75 Loss: 0.00531
# 1/1 [==============================] - 0s 26ms/step
# Frame 76 Loss: 0.00555
# 1/1 [==============================] - 0s 26ms/step
# Frame 77 Loss: 0.00593
# 1/1 [==============================] - 0s 28ms/step
# Frame 78 Loss: 0.00737
# 1/1 [==============================] - 0s 26ms/step
# Frame 79 Loss: 0.00774
# 1/1 [==============================] - 0s 27ms/step
# Frame 80 Loss: 0.00705
# 1/1 [==============================] - 0s 25ms/step
# Frame 81 Loss: 0.00689
# 1/1 [==============================] - 0s 25ms/step
# Frame 82 Loss: 0.00668
# 1/1 [==============================] - 0s 26ms/step
# Frame 83 Loss: 0.00594
# 1/1 [==============================] - 0s 25ms/step
# Frame 84 Loss: 0.00628
# 1/1 [==============================] - 0s 26ms/step
# Frame 85 Loss: 0.00658
# 1/1 [==============================] - 0s 27ms/step
# Frame 86 Loss: 0.00598
# 1/1 [==============================] - 0s 26ms/step
# Frame 87 Loss: 0.00619
# 1/1 [==============================] - 0s 26ms/step
# Frame 88 Loss: 0.00621
# 1/1 [==============================] - 0s 26ms/step
# Frame 89 Loss: 0.00667
# 1/1 [==============================] - 0s 28ms/step
# Frame 90 Loss: 0.00716
# 1/1 [==============================] - 0s 26ms/step
# Frame 91 Loss: 0.00684
# 1/1 [==============================] - 0s 25ms/step
# Frame 92 Loss: 0.00720
# 1/1 [==============================] - 0s 24ms/step
# Frame 93 Loss: 0.00708
# 1/1 [==============================] - 0s 32ms/step
# Frame 94 Loss: 0.00687
# 1/1 [==============================] - 0s 35ms/step
# Frame 95 Loss: 0.00627
# 1/1 [==============================] - 0s 27ms/step
# Frame 96 Loss: 0.00635
# 1/1 [==============================] - 0s 27ms/step
# Frame 97 Loss: 0.00668
# 1/1 [==============================] - 0s 29ms/step
# Frame 98 Loss: 0.00746
# 1/1 [==============================] - 0s 25ms/step
# Frame 99 Loss: 0.00801
# 1/1 [==============================] - 0s 28ms/step
# Frame 100 Loss: 0.00837
# Processed 100 frames, found 47 anomalies so far.
# 1/1 [==============================] - 0s 27ms/step
# Frame 101 Loss: 0.00768
# 1/1 [==============================] - 0s 24ms/step
# Frame 102 Loss: 0.00739
# 1/1 [==============================] - 0s 27ms/step
# Frame 103 Loss: 0.00738
# 1/1 [==============================] - 0s 27ms/step
# Frame 104 Loss: 0.00703
# 1/1 [==============================] - 0s 27ms/step
# Frame 105 Loss: 0.00644
# 1/1 [==============================] - 0s 26ms/step
# Frame 106 Loss: 0.00727
# 1/1 [==============================] - 0s 24ms/step
# Frame 107 Loss: 0.00888
# 1/1 [==============================] - 0s 26ms/step
# Frame 108 Loss: 0.00877
# 1/1 [==============================] - 0s 27ms/step
# Frame 109 Loss: 0.00812
# 1/1 [==============================] - 0s 27ms/step
# Frame 110 Loss: 0.00815
# 1/1 [==============================] - 0s 27ms/step
# Frame 111 Loss: 0.00740
# 1/1 [==============================] - 0s 26ms/step
# Frame 112 Loss: 0.00714
# 1/1 [==============================] - 0s 27ms/step
# Frame 113 Loss: 0.00728
# 1/1 [==============================] - 0s 23ms/step
# Frame 114 Loss: 0.00688
# 1/1 [==============================] - 0s 24ms/step
# Frame 115 Loss: 0.00702
# 1/1 [==============================] - 0s 26ms/step
# Frame 116 Loss: 0.00799
# 1/1 [==============================] - 0s 33ms/step
# Frame 117 Loss: 0.00873
# 1/1 [==============================] - 0s 26ms/step
# Frame 118 Loss: 0.00851
# 1/1 [==============================] - 0s 28ms/step
# Frame 119 Loss: 0.00791
# 1/1 [==============================] - 0s 27ms/step
# Frame 120 Loss: 0.00755
# 1/1 [==============================] - 0s 27ms/step
# Frame 121 Loss: 0.00826
# 1/1 [==============================] - 0s 25ms/step
# Frame 122 Loss: 0.00898
# 1/1 [==============================] - 0s 25ms/step
# Frame 123 Loss: 0.00932
# 1/1 [==============================] - 0s 27ms/step
# Frame 124 Loss: 0.00912
# 1/1 [==============================] - 0s 27ms/step
# Frame 125 Loss: 0.00901
# 1/1 [==============================] - 0s 27ms/step
# Frame 126 Loss: 0.00956
# 1/1 [==============================] - 0s 27ms/step
# Frame 127 Loss: 0.00921
# 1/1 [==============================] - 0s 28ms/step
# Frame 128 Loss: 0.00917
# 1/1 [==============================] - 0s 26ms/step
# Frame 129 Loss: 0.00865
# 1/1 [==============================] - 0s 27ms/step
# Frame 130 Loss: 0.00881
# 1/1 [==============================] - 0s 26ms/step
# Frame 131 Loss: 0.00879
# 1/1 [==============================] - 0s 26ms/step
# Frame 132 Loss: 0.00842
# 1/1 [==============================] - 0s 28ms/step
# Frame 133 Loss: 0.00863
# 1/1 [==============================] - 0s 28ms/step
# Frame 134 Loss: 0.00906
# 1/1 [==============================] - 0s 35ms/step
# Frame 135 Loss: 0.01069
# 1/1 [==============================] - 0s 32ms/step
# Frame 136 Loss: 0.00911
# 1/1 [==============================] - 0s 27ms/step
# Frame 137 Loss: 0.00863
# 1/1 [==============================] - 0s 26ms/step
# Frame 138 Loss: 0.01003
# 1/1 [==============================] - 0s 25ms/step
# Frame 139 Loss: 0.01155
# 1/1 [==============================] - 0s 24ms/step
# Frame 140 Loss: 0.00958
# 1/1 [==============================] - 0s 26ms/step
# Frame 141 Loss: 0.00913
# 1/1 [==============================] - 0s 26ms/step
# Frame 142 Loss: 0.01213
# 1/1 [==============================] - 0s 25ms/step
# Frame 143 Loss: 0.01108
# 1/1 [==============================] - 0s 26ms/step
# Frame 144 Loss: 0.00959
# 1/1 [==============================] - 0s 30ms/step
# Frame 145 Loss: 0.01268
# 1/1 [==============================] - 0s 27ms/step
# Frame 146 Loss: 0.01077
# 1/1 [==============================] - 0s 23ms/step
# Frame 147 Loss: 0.01014
# 1/1 [==============================] - 0s 25ms/step
# Frame 148 Loss: 0.01262
# 1/1 [==============================] - 0s 29ms/step
# Frame 149 Loss: 0.01405
# 1/1 [==============================] - 0s 27ms/step
# Frame 150 Loss: 0.01040
# 1/1 [==============================] - 0s 25ms/step
# Frame 151 Loss: 0.01575
# 1/1 [==============================] - 0s 25ms/step
# Frame 152 Loss: 0.01487
# 1/1 [==============================] - 0s 27ms/step
# Frame 153 Loss: 0.01349
# 1/1 [==============================] - 0s 28ms/step
# Frame 154 Loss: 0.01942
# 1/1 [==============================] - 0s 28ms/step
# Frame 155 Loss: 0.01863
# 1/1 [==============================] - 0s 26ms/step
# Frame 156 Loss: 0.01612
# 1/1 [==============================] - 0s 31ms/step
# Frame 157 Loss: 0.02067
# 1/1 [==============================] - 0s 24ms/step
# Frame 158 Loss: 0.01625
# 1/1 [==============================] - 0s 25ms/step
# Frame 159 Loss: 0.01861
# 1/1 [==============================] - 0s 25ms/step
# Frame 160 Loss: 0.01843
# 1/1 [==============================] - 0s 26ms/step
# Frame 161 Loss: 0.01487
# 1/1 [==============================] - 0s 26ms/step
# Frame 162 Loss: 0.01496
# 1/1 [==============================] - 0s 24ms/step
# Frame 163 Loss: 0.01585
# 1/1 [==============================] - 0s 23ms/step
# Frame 164 Loss: 0.01529
# 1/1 [==============================] - 0s 26ms/step
# Frame 165 Loss: 0.01565
# 1/1 [==============================] - 0s 28ms/step
# Frame 166 Loss: 0.01676
# 1/1 [==============================] - 0s 24ms/step
# Frame 167 Loss: 0.01497
# 1/1 [==============================] - 0s 22ms/step
# Frame 168 Loss: 0.01319
# 1/1 [==============================] - 0s 26ms/step
# Frame 169 Loss: 0.00977
# 1/1 [==============================] - 0s 25ms/step
# Frame 170 Loss: 0.00498
# 1/1 [==============================] - 0s 22ms/step
# Frame 171 Loss: 0.00379
# 1/1 [==============================] - 0s 25ms/step
# Frame 172 Loss: 0.00336
# 1/1 [==============================] - 0s 24ms/step
# Frame 173 Loss: 0.00341
# 1/1 [==============================] - 0s 25ms/step
# Frame 174 Loss: 0.00345
# 1/1 [==============================] - 0s 25ms/step
# Frame 175 Loss: 0.00349
# 1/1 [==============================] - 0s 37ms/step
# Frame 176 Loss: 0.00348
# 1/1 [==============================] - 0s 29ms/step
# Frame 177 Loss: 0.00350
# 1/1 [==============================] - 0s 25ms/step
# Frame 178 Loss: 0.00349
# 1/1 [==============================] - 0s 25ms/step
# Frame 179 Loss: 0.00352
# 1/1 [==============================] - 0s 24ms/step
# Frame 180 Loss: 0.00351
# 1/1 [==============================] - 0s 24ms/step
# Frame 181 Loss: 0.00351
# 1/1 [==============================] - 0s 25ms/step
# Frame 182 Loss: 0.00344
# 1/1 [==============================] - 0s 23ms/step
# Frame 183 Loss: 0.00343
# 1/1 [==============================] - 0s 25ms/step
# Frame 184 Loss: 0.00344
# 1/1 [==============================] - 0s 25ms/step
# Frame 185 Loss: 0.00351
# 1/1 [==============================] - 0s 25ms/step
# Frame 186 Loss: 0.00353
# 1/1 [==============================] - 0s 28ms/step
# Frame 187 Loss: 0.00346
# 1/1 [==============================] - 0s 25ms/step
# Frame 188 Loss: 0.00352
# 1/1 [==============================] - 0s 27ms/step
# Frame 189 Loss: 0.00351
# 1/1 [==============================] - 0s 27ms/step
# Frame 190 Loss: 0.00354
# 1/1 [==============================] - 0s 25ms/step
# Frame 191 Loss: 0.00354
# 1/1 [==============================] - 0s 27ms/step
# Frame 192 Loss: 0.00353
# 1/1 [==============================] - 0s 28ms/step
# Frame 193 Loss: 0.00353
# 1/1 [==============================] - 0s 26ms/step
# Frame 194 Loss: 0.00349
# 1/1 [==============================] - 0s 28ms/step
# Frame 195 Loss: 0.00349
# 1/1 [==============================] - 0s 27ms/step
# Frame 196 Loss: 0.00347
# 1/1 [==============================] - 0s 28ms/step
# Frame 197 Loss: 0.00345
# 1/1 [==============================] - 0s 24ms/step
# Frame 198 Loss: 0.00345
# 1/1 [==============================] - 0s 23ms/step
# Frame 199 Loss: 0.00345
# 1/1 [==============================] - 0s 25ms/step
# Frame 200 Loss: 0.00340
# Processed 200 frames, found 117 anomalies so far.
# End of video or issue reading frame.
#
# Processing complete!
# Total frames processed: 200
# Total anomalies detected: 117
# Anomaly rate: 58.50%

# %% [markdown]
# ## Output with graph analysis

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import imutils
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# Adjusted threshold for overall frame anomaly detection
ANOMALY_THRESHOLD = 0.00435
ANOMALY_REGION_PIXEL_THRESHOLD = 0.200

# Define model and video paths
model_dir = "../models/model_e50_b4.h5"
video_path = "D:\\Research Dataset\\Surveillance\\Test\\testing_video.mp4"
output_video_path = "loss_graph_video.mp4" # Path to save the plot video
plot_frame_dir = "plot_frames" # Directory to save individual plot frames

# Create output directories if they don't exist
if not os.path.exists("output_frames"):
    os.makedirs("output_frames")
if not os.path.exists("reconstructed_frames"):
    os.makedirs("reconstructed_frames")
if not os.path.exists("anomaly_maps"):
    os.makedirs("anomaly_maps")
if not os.path.exists(plot_frame_dir):
    os.makedirs(plot_frame_dir)

# Lists to store frame loss data and frame numbers
frame_losses = []
frame_numbers = []
frame_count_processed = 0
anomaly_count = 0


# Function to calculate Mean Squared Error (MSE) loss
def mean_squared_loss(x1, x2):
    x1_np = x1.numpy() if tf.is_tensor(x1) else x1
    x2_np = x2.numpy() if tf.is_tensor(x2) else x2
    difference = x1_np.flatten() - x2_np.flatten()
    sq_difference = difference ** 2
    mse = np.mean(sq_difference)
    return mse

# Custom loss function for Keras model loading
def combined_loss(y_true, y_pred):
    mse_loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
    return mse_loss

# Function to preprocess frames for the model
def preprocess_frame_for_new_model(frame):
    frame_resized = cv2.resize(frame, (232, 232), interpolation=cv2.INTER_AREA)
    gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
    gray = gray.astype(np.float32) / 255.0
    gray = (gray - 0.5) * 2
    return gray

# Load the pre-trained Keras model
custom_objects = {'combined_loss': combined_loss}
try:
    model = load_model(model_dir, custom_objects=custom_objects)
    print("Frame-by-frame model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Please ensure 'model.h5' is in the '../models/' directory and the custom loss function is defined.")
    exit()

# Open the video file
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit()
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total frames in video: {length}")


# Initialize the plot
fig, ax = plt.subplots()
line, = ax.plot(frame_numbers, frame_losses)
ax.set_xlabel('Frame Number')
ax.set_ylabel('Mean Squared Error (MSE)')
ax.set_title('Real-time Reconstruction Loss')
ax.grid(True)

# Set initial fixed x-axis limits
initial_x_limit = length
ax.set_xlim(0, initial_x_limit)
# Set initial fixed y-axis limits from 0 to 2
ax.set_ylim(0, 0.030) ## I may need to adjust it

# Main loop for frame processing
while True:
    ret, raw_frame = cap.read()
    if not ret:
        print("End of video.")
        break

    frame_count_processed += 1
    original_frame_color = imutils.resize(raw_frame, width=700, height=600)
    processed_frame = preprocess_frame_for_new_model(raw_frame)
    model_input_frame = np.expand_dims(np.expand_dims(processed_frame, axis=0), axis=-1)
    output = model.predict(model_input_frame)
    reconstructed_frame_2d = output[0, :, :, 0]
    reconstructed_frame_display = ((reconstructed_frame_2d + 1) / 2 * 255).astype(np.uint8)
    reconstructed_frame_display = cv2.resize(
        reconstructed_frame_display, (original_frame_color.shape[1], original_frame_color.shape[0])
    )
    cv2.imwrite(f"reconstructed_frames/frame_{frame_count_processed:05d}_reconstructed.jpg", reconstructed_frame_display)

    loss = mean_squared_loss(model_input_frame, output)
    loss_display = f"{loss:.5f}"
    print(f"Frame {frame_count_processed} Loss: {loss_display}")

    frame_losses.append(loss)
    frame_numbers.append(frame_count_processed)

    # Update the plot data
    line.set_xdata(frame_numbers)
    line.set_ydata(frame_losses)

    # Dynamically adjust x-axis limits for scrolling effect
    if frame_count_processed > initial_x_limit:
        ax.set_xlim(frame_count_processed - initial_x_limit, frame_count_processed)
    else:
        ax.set_xlim(0, initial_x_limit)

    # Redraw the canvas and save the plot frame
    fig.canvas.draw()
    plot_frame_filename = os.path.join(plot_frame_dir, f"plot_frame_{frame_count_processed:05d}.png")
    fig.savefig(plot_frame_filename) # Save the plot as an image

    display_frame = original_frame_color.copy()
    status_text = f"Normal: {loss_display}"
    color = (0, 255, 0)

    if loss > ANOMALY_THRESHOLD:
        status_text = f"Anomaly: {loss_display}"
        color = (0, 0, 255)
        anomaly_count += 1

        # --- Anomaly Localization with Overlay ---
        squared_diff_map = (processed_frame - reconstructed_frame_2d)**2
        # Normalize the squared difference map to [0, 255] for thresholding
        scaled_diff_map = (squared_diff_map * 255).astype(np.uint8)
        _, binary_error_mask = cv2.threshold(
            scaled_diff_map,
            int(ANOMALY_REGION_PIXEL_THRESHOLD * 255),
            255,
            cv2.THRESH_BINARY
        )
        binary_error_mask_resized = cv2.resize(
            binary_error_mask, (original_frame_color.shape[1], original_frame_color.shape[0]),
            interpolation=cv2.INTER_NEAREST
        )
        contours, _ = cv2.findContours(
            binary_error_mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
        )
        for contour in contours:
            if cv2.contourArea(contour) > 50:
                x, y, w, h = cv2.boundingRect(contour)
                overlay = display_frame.copy()
                cv2.rectangle(overlay, (x, y), (x + w, y + h), (0, 0, 255), -1)
                alpha = 0.50
                display_frame = cv2.addWeighted(overlay, alpha, display_frame, 1 - alpha, 0)
        # --- End Anomaly Localization ---

    cv2.putText(display_frame, status_text, (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
    cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}.jpg", display_frame)
    cv2.imshow("Anomaly Detection", display_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting video processing.")
        break

# Release video capture and destroy all OpenCV windows
cap.release()
cv2.destroyAllWindows()
plt.close(fig) # Close the Matplotlib figure

print(f"\nProcessing complete!")
print(f"Total frames processed: {frame_count_processed}")
print(f"Total anomalies detected: {anomaly_count}")
if frame_count_processed > 0:
    anomaly_rate = (anomaly_count / frame_count_processed * 100)
    print(f"Anomaly rate: {anomaly_rate:.2f}%")
else:
    print("No frames were processed, cannot calculate anomaly rate.")

# Save the final loss data to a CSV file
loss_data = np.array([frame_numbers, frame_losses]).T
np.savetxt("loss_data_final.csv", loss_data, delimiter=",", header="frame_number,loss", comments="")
print("Final loss information saved to loss_data_final.csv")
## 54.8 sec without trt model
# Out:
# Frame-by-frame model loaded successfully.
# Total frames in video: 200
# 1/1 [==============================] - 7s 7s/step
# Frame 1 Loss: 0.00275
# 1/1 [==============================] - 0s 17ms/step
# Frame 2 Loss: 0.00274
# 1/1 [==============================] - 0s 17ms/step
# Frame 3 Loss: 0.00278
# 1/1 [==============================] - 0s 18ms/step
# Frame 4 Loss: 0.00272
# 1/1 [==============================] - 0s 19ms/step
# Frame 5 Loss: 0.00272
# 1/1 [==============================] - 0s 19ms/step
# Frame 6 Loss: 0.00278
# 1/1 [==============================] - 0s 17ms/step
# Frame 7 Loss: 0.00280
# 1/1 [==============================] - 0s 20ms/step
# Frame 8 Loss: 0.00282
# 1/1 [==============================] - 0s 18ms/step
# Frame 9 Loss: 0.00287
# 1/1 [==============================] - 0s 18ms/step
# Frame 10 Loss: 0.00281
# 1/1 [==============================] - 0s 18ms/step
# Frame 11 Loss: 0.00278
# 1/1 [==============================] - 0s 19ms/step
# Frame 12 Loss: 0.00273
# 1/1 [==============================] - 0s 17ms/step
# Frame 13 Loss: 0.00287
# 1/1 [==============================] - 0s 16ms/step
# Frame 14 Loss: 0.00271
# 1/1 [==============================] - 0s 18ms/step
# Frame 15 Loss: 0.00267
# 1/1 [==============================] - 0s 17ms/step
# Frame 16 Loss: 0.00268
# 1/1 [==============================] - 0s 17ms/step
# Frame 17 Loss: 0.00273
# 1/1 [==============================] - 0s 18ms/step
# Frame 18 Loss: 0.00272
# 1/1 [==============================] - 0s 19ms/step
# Frame 19 Loss: 0.00271
# 1/1 [==============================] - 0s 23ms/step
# Frame 20 Loss: 0.00279
# 1/1 [==============================] - 0s 16ms/step
# Frame 21 Loss: 0.00272
# 1/1 [==============================] - 0s 17ms/step
# Frame 22 Loss: 0.00265
# 1/1 [==============================] - 0s 16ms/step
# Frame 23 Loss: 0.00270
# 1/1 [==============================] - 0s 17ms/step
# Frame 24 Loss: 0.00269
# 1/1 [==============================] - 0s 16ms/step
# Frame 25 Loss: 0.00274
# 1/1 [==============================] - 0s 17ms/step
# Frame 26 Loss: 0.00262
# 1/1 [==============================] - 0s 17ms/step
# Frame 27 Loss: 0.00257
# 1/1 [==============================] - 0s 18ms/step
# Frame 28 Loss: 0.00258
# 1/1 [==============================] - 0s 17ms/step
# Frame 29 Loss: 0.00256
# 1/1 [==============================] - 0s 16ms/step
# Frame 30 Loss: 0.00256
# 1/1 [==============================] - 0s 16ms/step
# Frame 31 Loss: 0.00255
# 1/1 [==============================] - 0s 15ms/step
# Frame 32 Loss: 0.00253
# 1/1 [==============================] - 0s 17ms/step
# Frame 33 Loss: 0.00258
# 1/1 [==============================] - 0s 16ms/step
# Frame 34 Loss: 0.00259
# 1/1 [==============================] - 0s 18ms/step
# Frame 35 Loss: 0.00256
# 1/1 [==============================] - 0s 16ms/step
# Frame 36 Loss: 0.00259
# 1/1 [==============================] - 0s 15ms/step
# Frame 37 Loss: 0.00263
# 1/1 [==============================] - 0s 17ms/step
# Frame 38 Loss: 0.00262
# 1/1 [==============================] - 0s 16ms/step
# Frame 39 Loss: 0.00258
# 1/1 [==============================] - 0s 16ms/step
# Frame 40 Loss: 0.00258
# 1/1 [==============================] - 0s 17ms/step
# Frame 41 Loss: 0.00262
# 1/1 [==============================] - 0s 18ms/step
# Frame 42 Loss: 0.00272
# 1/1 [==============================] - 0s 17ms/step
# Frame 43 Loss: 0.00280
# 1/1 [==============================] - 0s 20ms/step
# Frame 44 Loss: 0.00285
# 1/1 [==============================] - 0s 18ms/step
# Frame 45 Loss: 0.00284
# 1/1 [==============================] - 0s 17ms/step
# Frame 46 Loss: 0.00282
# 1/1 [==============================] - 0s 17ms/step
# Frame 47 Loss: 0.00288
# 1/1 [==============================] - 0s 17ms/step
# Frame 48 Loss: 0.00280
# 1/1 [==============================] - 0s 18ms/step
# Frame 49 Loss: 0.00304
# 1/1 [==============================] - 0s 19ms/step
# Frame 50 Loss: 0.00300
# 1/1 [==============================] - 0s 20ms/step
# Frame 51 Loss: 0.00288
# 1/1 [==============================] - 0s 17ms/step
# Frame 52 Loss: 0.00285
# 1/1 [==============================] - 0s 17ms/step
# Frame 53 Loss: 0.00302
# 1/1 [==============================] - 0s 16ms/step
# Frame 54 Loss: 0.00302
# 1/1 [==============================] - 0s 16ms/step
# Frame 55 Loss: 0.00305
# 1/1 [==============================] - 0s 21ms/step
# Frame 56 Loss: 0.00314
# 1/1 [==============================] - 0s 18ms/step
# Frame 57 Loss: 0.00300
# 1/1 [==============================] - 0s 18ms/step
# Frame 58 Loss: 0.00315
# 1/1 [==============================] - 0s 18ms/step
# Frame 59 Loss: 0.00405
# 1/1 [==============================] - 0s 18ms/step
# Frame 60 Loss: 0.00375
# 1/1 [==============================] - 0s 17ms/step
# Frame 61 Loss: 0.00335
# 1/1 [==============================] - 0s 16ms/step
# Frame 62 Loss: 0.00317
# 1/1 [==============================] - 0s 17ms/step
# Frame 63 Loss: 0.00326
# 1/1 [==============================] - 0s 16ms/step
# Frame 64 Loss: 0.00354
# 1/1 [==============================] - 0s 17ms/step
# Frame 65 Loss: 0.00478
# 1/1 [==============================] - 0s 18ms/step
# Frame 66 Loss: 0.00471
# 1/1 [==============================] - 0s 17ms/step
# Frame 67 Loss: 0.00415
# 1/1 [==============================] - 0s 17ms/step
# Frame 68 Loss: 0.00368
# 1/1 [==============================] - 0s 17ms/step
# Frame 69 Loss: 0.00353
# 1/1 [==============================] - 0s 17ms/step
# Frame 70 Loss: 0.00379
# 1/1 [==============================] - 0s 17ms/step
# Frame 71 Loss: 0.00449
# 1/1 [==============================] - 0s 18ms/step
# Frame 72 Loss: 0.00393
# 1/1 [==============================] - 0s 17ms/step
# Frame 73 Loss: 0.00396
# 1/1 [==============================] - 0s 17ms/step
# Frame 74 Loss: 0.00497
# 1/1 [==============================] - 0s 19ms/step
# Frame 75 Loss: 0.00695
# 1/1 [==============================] - 0s 16ms/step
# Frame 76 Loss: 0.00708
# 1/1 [==============================] - 0s 17ms/step
# Frame 77 Loss: 0.00652
# 1/1 [==============================] - 0s 17ms/step
# Frame 78 Loss: 0.00613
# 1/1 [==============================] - 0s 16ms/step
# Frame 79 Loss: 0.00496
# 1/1 [==============================] - 0s 17ms/step
# Frame 80 Loss: 0.00544
# 1/1 [==============================] - 0s 18ms/step
# Frame 81 Loss: 0.00594
# 1/1 [==============================] - 0s 17ms/step
# Frame 82 Loss: 0.00569
# 1/1 [==============================] - 0s 16ms/step
# Frame 83 Loss: 0.00598
# 1/1 [==============================] - 0s 17ms/step
# Frame 84 Loss: 0.00631
# 1/1 [==============================] - 0s 18ms/step
# Frame 85 Loss: 0.00643
# 1/1 [==============================] - 0s 19ms/step
# Frame 86 Loss: 0.00717
# 1/1 [==============================] - 0s 17ms/step
# Frame 87 Loss: 0.00667
# 1/1 [==============================] - 0s 17ms/step
# Frame 88 Loss: 0.00598
# 1/1 [==============================] - 0s 17ms/step
# Frame 89 Loss: 0.00579
# 1/1 [==============================] - 0s 16ms/step
# Frame 90 Loss: 0.00588
# 1/1 [==============================] - 0s 17ms/step
# Frame 91 Loss: 0.00592
# 1/1 [==============================] - 0s 18ms/step
# Frame 92 Loss: 0.00705
# 1/1 [==============================] - 0s 17ms/step
# Frame 93 Loss: 0.00654
# 1/1 [==============================] - 0s 17ms/step
# Frame 94 Loss: 0.00750
# 1/1 [==============================] - 0s 18ms/step
# Frame 95 Loss: 0.00916
# 1/1 [==============================] - 0s 20ms/step
# Frame 96 Loss: 0.00980
# 1/1 [==============================] - 0s 18ms/step
# Frame 97 Loss: 0.00899
# 1/1 [==============================] - 0s 17ms/step
# Frame 98 Loss: 0.00786
# 1/1 [==============================] - 0s 18ms/step
# Frame 99 Loss: 0.00688
# 1/1 [==============================] - 0s 18ms/step
# Frame 100 Loss: 0.00667
# 1/1 [==============================] - 0s 18ms/step
# Frame 101 Loss: 0.00710
# 1/1 [==============================] - 0s 16ms/step
# Frame 102 Loss: 0.00700
# 1/1 [==============================] - 0s 17ms/step
# Frame 103 Loss: 0.00798
# 1/1 [==============================] - 0s 16ms/step
# Frame 104 Loss: 0.00906
# 1/1 [==============================] - 0s 17ms/step
# Frame 105 Loss: 0.00985
# 1/1 [==============================] - 0s 16ms/step
# Frame 106 Loss: 0.01029
# 1/1 [==============================] - 0s 15ms/step
# Frame 107 Loss: 0.00933
# 1/1 [==============================] - 0s 17ms/step
# Frame 108 Loss: 0.00783
# 1/1 [==============================] - 0s 16ms/step
# Frame 109 Loss: 0.00755
# 1/1 [==============================] - 0s 17ms/step
# Frame 110 Loss: 0.00877
# 1/1 [==============================] - 0s 15ms/step
# Frame 111 Loss: 0.00783
# 1/1 [==============================] - 0s 17ms/step
# Frame 112 Loss: 0.00741
# 1/1 [==============================] - 0s 15ms/step
# Frame 113 Loss: 0.00836
# 1/1 [==============================] - 0s 15ms/step
# Frame 114 Loss: 0.01024
# 1/1 [==============================] - 0s 16ms/step
# Frame 115 Loss: 0.01062
# 1/1 [==============================] - 0s 16ms/step
# Frame 116 Loss: 0.01032
# 1/1 [==============================] - 0s 16ms/step
# Frame 117 Loss: 0.00967
# 1/1 [==============================] - 0s 17ms/step
# Frame 118 Loss: 0.00953
# 1/1 [==============================] - 0s 16ms/step
# Frame 119 Loss: 0.00949
# 1/1 [==============================] - 0s 16ms/step
# Frame 120 Loss: 0.00965
# 1/1 [==============================] - 0s 16ms/step
# Frame 121 Loss: 0.01262
# 1/1 [==============================] - 0s 17ms/step
# Frame 122 Loss: 0.01267
# 1/1 [==============================] - 0s 16ms/step
# Frame 123 Loss: 0.01130
# 1/1 [==============================] - 0s 16ms/step
# Frame 124 Loss: 0.01088
# 1/1 [==============================] - 0s 17ms/step
# Frame 125 Loss: 0.01075
# 1/1 [==============================] - 0s 17ms/step
# Frame 126 Loss: 0.01181
# 1/1 [==============================] - 0s 16ms/step
# Frame 127 Loss: 0.01228
# 1/1 [==============================] - 0s 17ms/step
# Frame 128 Loss: 0.01300
# 1/1 [==============================] - 0s 17ms/step
# Frame 129 Loss: 0.00955
# 1/1 [==============================] - 0s 17ms/step
# Frame 130 Loss: 0.00915
# 1/1 [==============================] - 0s 15ms/step
# Frame 131 Loss: 0.01021
# 1/1 [==============================] - 0s 17ms/step
# Frame 132 Loss: 0.01113
# 1/1 [==============================] - 0s 15ms/step
# Frame 133 Loss: 0.01393
# 1/1 [==============================] - 0s 16ms/step
# Frame 134 Loss: 0.01043
# 1/1 [==============================] - 0s 16ms/step
# Frame 135 Loss: 0.01212
# 1/1 [==============================] - 0s 16ms/step
# Frame 136 Loss: 0.01225
# 1/1 [==============================] - 0s 16ms/step
# Frame 137 Loss: 0.01669
# 1/1 [==============================] - 0s 16ms/step
# Frame 138 Loss: 0.01042
# 1/1 [==============================] - 0s 15ms/step
# Frame 139 Loss: 0.01609
# 1/1 [==============================] - 0s 16ms/step
# Frame 140 Loss: 0.01294
# 1/1 [==============================] - 0s 16ms/step
# Frame 141 Loss: 0.01638
# 1/1 [==============================] - 0s 15ms/step
# Frame 142 Loss: 0.01311
# 1/1 [==============================] - 0s 15ms/step
# Frame 143 Loss: 0.01208
# 1/1 [==============================] - 0s 17ms/step
# Frame 144 Loss: 0.01955
# 1/1 [==============================] - 0s 16ms/step
# Frame 145 Loss: 0.01253
# 1/1 [==============================] - 0s 17ms/step
# Frame 146 Loss: 0.01848
# 1/1 [==============================] - 0s 16ms/step
# Frame 147 Loss: 0.01801
# 1/1 [==============================] - 0s 16ms/step
# Frame 148 Loss: 0.01528
# 1/1 [==============================] - 0s 16ms/step
# Frame 149 Loss: 0.01987
# 1/1 [==============================] - 0s 17ms/step
# Frame 150 Loss: 0.02081
# 1/1 [==============================] - 0s 15ms/step
# Frame 151 Loss: 0.01611
# 1/1 [==============================] - 0s 15ms/step
# Frame 152 Loss: 0.02131
# 1/1 [==============================] - 0s 16ms/step
# Frame 153 Loss: 0.02404
# 1/1 [==============================] - 0s 16ms/step
# Frame 154 Loss: 0.02218
# 1/1 [==============================] - 0s 16ms/step
# Frame 155 Loss: 0.02486
# 1/1 [==============================] - 0s 17ms/step
# Frame 156 Loss: 0.02787
# 1/1 [==============================] - 0s 16ms/step
# Frame 157 Loss: 0.02404
# 1/1 [==============================] - 0s 15ms/step
# Frame 158 Loss: 0.02518
# 1/1 [==============================] - 0s 16ms/step
# Frame 159 Loss: 0.01974
# 1/1 [==============================] - 0s 15ms/step
# Frame 160 Loss: 0.02080
# 1/1 [==============================] - 0s 17ms/step
# Frame 161 Loss: 0.01763
# 1/1 [==============================] - 0s 16ms/step
# Frame 162 Loss: 0.01669
# 1/1 [==============================] - 0s 16ms/step
# Frame 163 Loss: 0.01724
# 1/1 [==============================] - 0s 15ms/step
# Frame 164 Loss: 0.01659
# 1/1 [==============================] - 0s 16ms/step
# Frame 165 Loss: 0.01799
# 1/1 [==============================] - 0s 17ms/step
# Frame 166 Loss: 0.01653
# 1/1 [==============================] - 0s 16ms/step
# Frame 167 Loss: 0.01564
# 1/1 [==============================] - 0s 18ms/step
# Frame 168 Loss: 0.01369
# 1/1 [==============================] - 0s 17ms/step
# Frame 169 Loss: 0.01077
# 1/1 [==============================] - 0s 16ms/step
# Frame 170 Loss: 0.00723
# 1/1 [==============================] - 0s 16ms/step
# Frame 171 Loss: 0.00219
# 1/1 [==============================] - 0s 14ms/step
# Frame 172 Loss: 0.00178
# 1/1 [==============================] - 0s 15ms/step
# Frame 173 Loss: 0.00181
# 1/1 [==============================] - 0s 16ms/step
# Frame 174 Loss: 0.00185
# 1/1 [==============================] - 0s 16ms/step
# Frame 175 Loss: 0.00183
# 1/1 [==============================] - 0s 16ms/step
# Frame 176 Loss: 0.00182
# 1/1 [==============================] - 0s 16ms/step
# Frame 177 Loss: 0.00183
# 1/1 [==============================] - 0s 17ms/step
# Frame 178 Loss: 0.00187
# 1/1 [==============================] - 0s 16ms/step
# Frame 179 Loss: 0.00191
# 1/1 [==============================] - 0s 15ms/step
# Frame 180 Loss: 0.00189
# 1/1 [==============================] - 0s 15ms/step
# Frame 181 Loss: 0.00189
# 1/1 [==============================] - 0s 17ms/step
# Frame 182 Loss: 0.00184
# 1/1 [==============================] - 0s 17ms/step
# Frame 183 Loss: 0.00182
# 1/1 [==============================] - 0s 15ms/step
# Frame 184 Loss: 0.00184
# 1/1 [==============================] - 0s 16ms/step
# Frame 185 Loss: 0.00188
# 1/1 [==============================] - 0s 18ms/step
# Frame 186 Loss: 0.00185
# 1/1 [==============================] - 0s 15ms/step
# Frame 187 Loss: 0.00184
# 1/1 [==============================] - 0s 15ms/step
# Frame 188 Loss: 0.00189
# 1/1 [==============================] - 0s 16ms/step
# Frame 189 Loss: 0.00187
# 1/1 [==============================] - 0s 16ms/step
# Frame 190 Loss: 0.00192
# 1/1 [==============================] - 0s 15ms/step
# Frame 191 Loss: 0.00193
# 1/1 [==============================] - 0s 16ms/step
# Frame 192 Loss: 0.00192
# 1/1 [==============================] - 0s 16ms/step
# Frame 193 Loss: 0.00189
# 1/1 [==============================] - 0s 16ms/step
# Frame 194 Loss: 0.00186
# 1/1 [==============================] - 0s 16ms/step
# Frame 195 Loss: 0.00186
# 1/1 [==============================] - 0s 17ms/step
# Frame 196 Loss: 0.00188
# 1/1 [==============================] - 0s 16ms/step
# Frame 197 Loss: 0.00184
# 1/1 [==============================] - 0s 18ms/step
# Frame 198 Loss: 0.00183
# 1/1 [==============================] - 0s 17ms/step
# Frame 199 Loss: 0.00183
# 1/1 [==============================] - 0s 17ms/step
# Frame 200 Loss: 0.00179
# End of video.
#
# Processing complete!
# Total frames processed: 200
# Total anomalies detected: 100
# Anomaly rate: 50.00%
# Final loss information saved to loss_data_final.csv
