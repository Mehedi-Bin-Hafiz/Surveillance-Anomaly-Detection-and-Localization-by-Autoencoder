# %% [markdown]
# ## localize anomaly by detecting  generated abnormal pixels

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import imutils
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# Adjusted threshold for overall frame anomaly detection
# IMPORTANT: This threshold will likely need re-tuning after changing mean_squared_loss
ANOMALY_THRESHOLD = 0.00220 # A more typical unscaled MSE threshold for normalized data

# Threshold for identifying anomalous regions within a frame (for visualization)
# This value will likely need to be tuned based on your model's performance and data.
# It represents a pixel-wise squared error value.
ANOMALY_REGION_PIXEL_THRESHOLD = 0.00100 # Example value, tune this!

model_epochs = 16
model_dir = "../models/street_model_e16_b8.h5" # Path to the trained Keras model
video_path = "D:\\Research Dataset\\Minverva all videos\\Theia Street_View Videos\\input.mp4" # Path to the video file


# Ensure output folders exist
if not os.path.exists("output_frames"):
    os.makedirs("output_frames")
if not os.path.exists("reconstructed_frames"):
    os.makedirs("reconstructed_frames")
if not os.path.exists("anomaly_maps"): # New folder for error maps
    os.makedirs("anomaly_maps")
if not os.path.exists("output_video"): # New folder for graphs
    os.makedirs("output_video")

frame_count_processed = 0
anomaly_count = 0

# Lists to store loss values for graph
loss_values = []
frame_numbers = []

def mean_squared_loss(x1, x2):
    """
    Calculates the true Mean Squared Error (MSE) between two arrays.
    This function is now consistent with tf.keras.losses.mean_squared_error.
    Returns the MSE.
    """
    # Ensure inputs are numpy arrays for consistent calculation,
    # as 'output' from model.predict is typically a numpy array.
    # If x1 or x2 were TensorFlow tensors, .numpy() would convert them.
    x1_np = x1.numpy() if tf.is_tensor(x1) else x1
    x2_np = x2.numpy() if tf.is_tensor(x2) else x2

    # Flatten the arrays to compute element-wise difference
    difference = x1_np.flatten() - x2_np.flatten()
    sq_difference = difference ** 2
    mse = np.mean(sq_difference) # Correct MSE calculation
    return mse

def combined_loss(y_true, y_pred):
    """
    Custom combined loss function for the Keras model.
    Assumes mean squared error is the primary component.
    This function is used during model loading/compilation.
    """
    mse_loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
    return mse_loss

def preprocess_frame_for_new_model(frame):
    """
    Preprocess frame for the new model architecture.
    The new model expects normalized inputs (e.g., in [-1, 1] range).
    """
    frame_resized = cv2.resize(frame, (232, 232), interpolation=cv2.INTER_AREA)
    gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
    gray = gray.astype(np.float32) / 255.0 # Normalize to [0, 1]
    gray = (gray - 0.5) * 2 # Scale to [-1, 1]
    return gray

# Load the trained Keras model
custom_objects = {'combined_loss': combined_loss}
try:
    model = load_model(model_dir, custom_objects=custom_objects)
    print("Frame-by-frame model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Please ensure 'model.h5' is in the '../models/' directory and the custom loss function is defined.")
    exit()

# Open the video file for processing
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit()

length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total frames in video: {length}")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video or issue reading frame.")
        break

    frame_count_processed += 1

    # Resize original frame for consistent display
    original_frame_color = imutils.resize(frame, width=700, height=600)

    # Preprocess frame for the model
    processed_frame = preprocess_frame_for_new_model(frame)
    # Add batch and channel dimensions for model input (batch_size, height, width, channels)
    model_input_frame = np.expand_dims(np.expand_dims(processed_frame, axis=0), axis=-1)

    # Get model prediction (reconstructed frame)
    output = model.predict(model_input_frame)

    # Extract the 2D reconstructed frame from the model output
    reconstructed_frame_2d = output[0, :, :, 0]

    # --- Save Model Prediction (Individual Reconstructed Frame as Image) ---
    # Normalize reconstructed frame to [0, 255] for display and saving
    # If the model output is in [-1, 1], map it back to [0, 255]
    reconstructed_frame_display = ((reconstructed_frame_2d + 1) / 2 * 255).astype(np.uint8)
    # Resize reconstructed frame to match the display size of the original frame
    reconstructed_frame_display = cv2.resize(
        reconstructed_frame_display, (original_frame_color.shape[1], original_frame_color.shape[0])
    )
    # Save the reconstructed frame
    cv2.imwrite(f"reconstructed_frames/frame_{frame_count_processed:05d}_reconstructed.jpg", reconstructed_frame_display)
    # --- End Save Model Prediction (Image) ---
    
    # Calculate the overall reconstruction loss (MSE) for the frame
    loss = mean_squared_loss(model_input_frame, output)
    # Removed loss_scaled as it's not needed with the corrected MSE and threshold
    loss_display = f"{loss:.5f}"
    print(f"Frame {frame_count_processed} Loss: {loss_display}")

    # Store loss values for graph
    loss_values.append(loss)
    frame_numbers.append(frame_count_processed)

    display_frame = original_frame_color.copy()

    status_text = f"Normal" #: {loss_display}
    color = (0, 255, 0) # Green for normal

    # Check for overall frame anomaly
    if loss > ANOMALY_THRESHOLD:
        status_text = f"Anomaly" #: {loss_display}
        color = (0, 0, 255) # Red for abnormal
        anomaly_count += 1 # Increment anomaly count only when overall frame is abnormal

        # --- Anomaly Localization (only if the frame is considered abnormal) ---
        # Calculate the element-wise squared difference between original and reconstructed
        # Ensure both are in the same range (e.g., [-1, 1]) for this calculation
        squared_diff_map = (processed_frame - reconstructed_frame_2d)**2

        # Normalize the squared difference map to [0, 255] for visualization
        # This makes higher differences appear brighter
        error_map_display = cv2.normalize(
            squared_diff_map, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U
        )
        # Resize the error map to the display frame's dimensions
        error_map_display_resized = cv2.resize(
            error_map_display, (original_frame_color.shape[1], original_frame_color.shape[0]),
            interpolation=cv2.INTER_LINEAR
        )
        cv2.imwrite(f"anomaly_maps/frame_{frame_count_processed:05d}_error_map.jpg", error_map_display_resized)
        
        # Create a binary mask of high error regions
        # Scale ANOMALY_REGION_PIXEL_THRESHOLD to 255 for cv2.threshold if squared_diff_map is normalized
        # Or, directly threshold the squared_diff_map values.
        # Ensure the input to threshold is 8-bit unsigned integer
        _, binary_error_mask = cv2.threshold(
            (squared_diff_map * 255).astype(np.uint8), # Scale to 0-255 for thresholding
            (ANOMALY_REGION_PIXEL_THRESHOLD * 255), # Scale threshold too
            255,
            cv2.THRESH_BINARY
        )

        # Resize the binary mask to the display frame's dimensions
        binary_error_mask_resized = cv2.resize(
            binary_error_mask, (original_frame_color.shape[1], original_frame_color.shape[0]),
            interpolation=cv2.INTER_NEAREST # Use nearest for binary masks
        )

        # Find contours in the binary mask
        contours, _ = cv2.findContours(
            binary_error_mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
        )

        # Draw bounding boxes around significant anomalous regions
        for contour in contours:
            # Filter out small noise contours
            if cv2.contourArea(contour) > 50: # Adjust this area threshold as needed
                x, y, w, h = cv2.boundingRect(contour)

                # # Create a semi-transparent red overlay for the bounding box
                # overlay = display_frame.copy()
                # #cv2.rectangle(overlay, (x, y), (x + w, y + h), (100, 100, 240) , -1) # Filled red rectangle
                # alpha = 0.50 # Transparency factor. 0.0 is fully transparent, 1.0 is fully opaque.
                # display_frame = cv2.addWeighted(overlay, alpha, display_frame, 1 - alpha, 0)

                #Removed the line that draws the red border, leaving only the shade
                # if w > 30 and h > 30:  # Adjust these values as needed
                #     cv2.rectangle(display_frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
        # --- End Anomaly Localization ---

    # Put status text on the display frame
    cv2.putText(display_frame, status_text, (100, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1.8, color, 2)

    # Save the annotated frame to output_frames
    if status_text.startswith("Anomaly"):
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}.jpg", display_frame)
    else:
        cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}.jpg", display_frame)

    # Display the frame
    cv2.imshow("Anomaly Detection", display_frame)
    # Wait for a key press (1ms delay), exit on 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    # Print progress every 100 frames
    if frame_count_processed % 100 == 0:
        print(f"Processed {frame_count_processed} frames, found {anomaly_count} anomalies so far.")

# Release video capture and destroy all OpenCV windows
cap.release()
cv2.destroyAllWindows()

print(f"\nProcessing complete!")
print(f"Total frames processed: {frame_count_processed}")
print(f"Total anomalies detected: {anomaly_count}")
if frame_count_processed > 0:
    anomaly_rate = (anomaly_count / frame_count_processed * 100)
    print(f"Anomaly rate: {anomaly_rate:.2f}%")
else:
    print("No frames were processed, cannot calculate anomaly rate.")

# Create loss graph (adapted from second code)
max_loss = max(loss_values) if loss_values else 0
if loss_values:
    print("\nCreating loss graph...")
    plt.figure(figsize=(12, 6))
    plt.plot(frame_numbers, loss_values, 'b-', linewidth=1, label='Loss')
    plt.axhline(y=ANOMALY_THRESHOLD, color='r', linestyle='--', linewidth=2, label=f'Threshold ({ANOMALY_THRESHOLD})')
    plt.axhline(y=max_loss, color='g', linestyle='--', linewidth=2, label=f'Max Loss ({max_loss:.5f})')
    
    # Highlight anomaly points in red
    anomaly_indices = [i for i, loss in enumerate(loss_values) if loss > ANOMALY_THRESHOLD]
    if anomaly_indices:
        anomaly_frames = [frame_numbers[i] for i in anomaly_indices]
        anomaly_losses = [loss_values[i] for i in anomaly_indices]
        plt.scatter(anomaly_frames, anomaly_losses, color='red', s=20, alpha=0.8, label='Anomalies', zorder=5)
    
    plt.xlabel('Frame Number')
    plt.ylabel('Loss Value')
    plt.title(f'Frame-by-Frame Anomaly Detection Epochs {model_epochs}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    
    # Save graph
    graph_path = os.path.join("output_video", "loss_graph.png")
    plt.savefig(graph_path, dpi=150, bbox_inches='tight')
    plt.show()
    
    print(f"Loss graph saved: {graph_path}")
else:
    print("No loss values to plot graph.")
# Out:
# Frame-by-frame model loaded successfully.
# Total frames in video: 5106
# 1/1 [==============================] - 5s 5s/step
# Frame 1 Loss: 0.00185
# 1/1 [==============================] - 0s 31ms/step
# Frame 2 Loss: 0.00185
# 1/1 [==============================] - 0s 30ms/step
# Frame 3 Loss: 0.00185
# 1/1 [==============================] - 0s 34ms/step
# Frame 4 Loss: 0.00185
# 1/1 [==============================] - 0s 34ms/step
# Frame 5 Loss: 0.00185
# 1/1 [==============================] - 0s 31ms/step
# Frame 6 Loss: 0.00185
# 1/1 [==============================] - 0s 32ms/step
# Frame 7 Loss: 0.00185
# 1/1 [==============================] - 0s 35ms/step
# Frame 8 Loss: 0.00185
# 1/1 [==============================] - 0s 34ms/step
# Frame 9 Loss: 0.00183
# 1/1 [==============================] - 0s 37ms/step
# Frame 10 Loss: 0.00181
# 1/1 [==============================] - 0s 32ms/step
# Frame 11 Loss: 0.00179
# 1/1 [==============================] - 0s 34ms/step
# Frame 12 Loss: 0.00179
# 1/1 [==============================] - 0s 31ms/step
# Frame 13 Loss: 0.00179
# 1/1 [==============================] - 0s 21ms/step
# Frame 14 Loss: 0.00179
# 1/1 [==============================] - 0s 19ms/step
# Frame 15 Loss: 0.00179
# 1/1 [==============================] - 0s 18ms/step
# Frame 16 Loss: 0.00179
# 1/1 [==============================] - 0s 19ms/step
# Frame 17 Loss: 0.00180
# 1/1 [==============================] - 0s 22ms/step
# Frame 18 Loss: 0.00181
# 1/1 [==============================] - 0s 21ms/step
# Frame 19 Loss: 0.00182
# 1/1 [==============================] - 0s 22ms/step
# Frame 20 Loss: 0.00182
# 1/1 [==============================] - 0s 21ms/step
# Frame 21 Loss: 0.00183
# 1/1 [==============================] - 0s 18ms/step
# Frame 22 Loss: 0.00184
# 1/1 [==============================] - 0s 24ms/step
# Frame 23 Loss: 0.00184
# 1/1 [==============================] - 0s 19ms/step
# Frame 24 Loss: 0.00185
# 1/1 [==============================] - 0s 22ms/step
# Frame 25 Loss: 0.00185
# 1/1 [==============================] - 0s 24ms/step
# Frame 26 Loss: 0.00184
# 1/1 [==============================] - 0s 21ms/step
# Frame 27 Loss: 0.00185
# 1/1 [==============================] - 0s 23ms/step
# Frame 28 Loss: 0.00186
# 1/1 [==============================] - 0s 20ms/step
# Frame 29 Loss: 0.00186
# 1/1 [==============================] - 0s 18ms/step
# Frame 30 Loss: 0.00186
# 1/1 [==============================] - 0s 19ms/step
# Frame 31 Loss: 0.00186
# 1/1 [==============================] - 0s 18ms/step
# Frame 32 Loss: 0.00186
# 1/1 [==============================] - 0s 20ms/step
# Frame 33 Loss: 0.00185
# 1/1 [==============================] - 0s 18ms/step
# Frame 34 Loss: 0.00184
# 1/1 [==============================] - 0s 20ms/step
# Frame 35 Loss: 0.00185
# 1/1 [==============================] - 0s 19ms/step
# Frame 36 Loss: 0.00186
# 1/1 [==============================] - 0s 18ms/step
# Frame 37 Loss: 0.00186
# 1/1 [==============================] - 0s 18ms/step
# Frame 38 Loss: 0.00187
# 1/1 [==============================] - 0s 20ms/step
# Frame 39 Loss: 0.00187
# 1/1 [==============================] - 0s 21ms/step
# Frame 40 Loss: 0.00187
# 1/1 [==============================] - 0s 22ms/step
# Frame 41 Loss: 0.00187
# 1/1 [==============================] - 0s 18ms/step
# Frame 42 Loss: 0.00187
# 1/1 [==============================] - 0s 21ms/step
# Frame 43 Loss: 0.00186
# 1/1 [==============================] - 0s 19ms/step
# Frame 44 Loss: 0.00187
# 1/1 [==============================] - 0s 17ms/step
# Frame 45 Loss: 0.00186
# 1/1 [==============================] - 0s 19ms/step
# Frame 46 Loss: 0.00187
# 1/1 [==============================] - 0s 17ms/step
# Frame 47 Loss: 0.00186
# 1/1 [==============================] - 0s 19ms/step
# Frame 48 Loss: 0.00187
# 1/1 [==============================] - 0s 17ms/step
# Frame 49 Loss: 0.00186
# 1/1 [==============================] - 0s 18ms/step
# Frame 50 Loss: 0.00186
# 1/1 [==============================] - 0s 19ms/step
# Frame 51 Loss: 0.00186
# 1/1 [==============================] - 0s 20ms/step
# Frame 52 Loss: 0.00186
# 1/1 [==============================] - 0s 20ms/step
# Frame 53 Loss: 0.00186
# 1/1 [==============================] - 0s 21ms/step
# Frame 54 Loss: 0.00186
# 1/1 [==============================] - 0s 19ms/step
# Frame 55 Loss: 0.00186
# 1/1 [==============================] - 0s 19ms/step
# Frame 56 Loss: 0.00186
# 1/1 [==============================] - 0s 18ms/step
# Frame 57 Loss: 0.00185
# 1/1 [==============================] - 0s 17ms/step
# Frame 58 Loss: 0.00184
# 1/1 [==============================] - 0s 21ms/step
# Frame 59 Loss: 0.00185
# 1/1 [==============================] - 0s 17ms/step
# Frame 60 Loss: 0.00185
# 1/1 [==============================] - 0s 19ms/step
# Frame 61 Loss: 0.00186
# 1/1 [==============================] - 0s 18ms/step
# Frame 62 Loss: 0.00186
# 1/1 [==============================] - 0s 20ms/step
# Frame 63 Loss: 0.00187
# 1/1 [==============================] - 0s 19ms/step
# Frame 64 Loss: 0.00188
# 1/1 [==============================] - 0s 19ms/step
# Frame 65 Loss: 0.00188
# 1/1 [==============================] - 0s 20ms/step
# Frame 66 Loss: 0.00188
# 1/1 [==============================] - 0s 19ms/step
# Frame 67 Loss: 0.00189
# 1/1 [==============================] - 0s 19ms/step
# Frame 68 Loss: 0.00190
# 1/1 [==============================] - 0s 18ms/step
# Frame 69 Loss: 0.00191
# 1/1 [==============================] - 0s 21ms/step
# Frame 70 Loss: 0.00192
# 1/1 [==============================] - 0s 19ms/step
# Frame 71 Loss: 0.00193
# 1/1 [==============================] - 0s 19ms/step
# Frame 72 Loss: 0.00194
# 1/1 [==============================] - 0s 20ms/step
# Frame 73 Loss: 0.00194
# 1/1 [==============================] - 0s 19ms/step
# Frame 74 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 75 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 76 Loss: 0.00197
# 1/1 [==============================] - 0s 20ms/step
# Frame 77 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 78 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 79 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 80 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 81 Loss: 0.00197
# 1/1 [==============================] - 0s 22ms/step
# Frame 82 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 83 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 84 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 85 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 86 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 87 Loss: 0.00197
# 1/1 [==============================] - 0s 20ms/step
# Frame 88 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 89 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 90 Loss: 0.00198
# 1/1 [==============================] - 0s 19ms/step
# Frame 91 Loss: 0.00198
# 1/1 [==============================] - 0s 19ms/step
# Frame 92 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 93 Loss: 0.00198
# 1/1 [==============================] - 0s 17ms/step
# Frame 94 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 95 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 96 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 97 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 98 Loss: 0.00201
# 1/1 [==============================] - 0s 20ms/step
# Frame 99 Loss: 0.00202
# 1/1 [==============================] - 0s 19ms/step
# Frame 100 Loss: 0.00202
# Processed 100 frames, found 0 anomalies so far.
# 1/1 [==============================] - 0s 18ms/step
# Frame 101 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 102 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 103 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 104 Loss: 0.00201
# 1/1 [==============================] - 0s 19ms/step
# Frame 105 Loss: 0.00200
# 1/1 [==============================] - 0s 22ms/step
# Frame 106 Loss: 0.00200
# 1/1 [==============================] - 0s 19ms/step
# Frame 107 Loss: 0.00200
# 1/1 [==============================] - 0s 20ms/step
# Frame 108 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 109 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 110 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 111 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 112 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 113 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 114 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 115 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 116 Loss: 0.00202
# 1/1 [==============================] - 0s 19ms/step
# Frame 117 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 118 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 119 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 120 Loss: 0.00203
# 1/1 [==============================] - 0s 16ms/step
# Frame 121 Loss: 0.00202
# 1/1 [==============================] - 0s 19ms/step
# Frame 122 Loss: 0.00202
# 1/1 [==============================] - 0s 20ms/step
# Frame 123 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 124 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 125 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 126 Loss: 0.00204
# 1/1 [==============================] - 0s 23ms/step
# Frame 127 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 128 Loss: 0.00201
# 1/1 [==============================] - 0s 19ms/step
# Frame 129 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 130 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 131 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 132 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 133 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 134 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 135 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 136 Loss: 0.00201
# 1/1 [==============================] - 0s 20ms/step
# Frame 137 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 138 Loss: 0.00199
# 1/1 [==============================] - 0s 20ms/step
# Frame 139 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 140 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 141 Loss: 0.00199
# 1/1 [==============================] - 0s 19ms/step
# Frame 142 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 143 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 144 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 145 Loss: 0.00200
# 1/1 [==============================] - 0s 19ms/step
# Frame 146 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 147 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 148 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 149 Loss: 0.00199
# 1/1 [==============================] - 0s 19ms/step
# Frame 150 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 151 Loss: 0.00198
# 1/1 [==============================] - 0s 19ms/step
# Frame 152 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 153 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 154 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 155 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 156 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 157 Loss: 0.00197
# 1/1 [==============================] - 0s 21ms/step
# Frame 158 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 159 Loss: 0.00198
# 1/1 [==============================] - 0s 17ms/step
# Frame 160 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 161 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 162 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 163 Loss: 0.00200
# 1/1 [==============================] - 0s 19ms/step
# Frame 164 Loss: 0.00201
# 1/1 [==============================] - 0s 19ms/step
# Frame 165 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 166 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 167 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 168 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 169 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 170 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 171 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 172 Loss: 0.00205
# 1/1 [==============================] - 0s 18ms/step
# Frame 173 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 174 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 175 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 176 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 177 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 178 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 179 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 180 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 181 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 182 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 183 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 184 Loss: 0.00201
# 1/1 [==============================] - 0s 21ms/step
# Frame 185 Loss: 0.00201
# 1/1 [==============================] - 0s 20ms/step
# Frame 186 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 187 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 188 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 189 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 190 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 191 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 192 Loss: 0.00202
# 1/1 [==============================] - 0s 20ms/step
# Frame 193 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 194 Loss: 0.00202
# 1/1 [==============================] - 0s 21ms/step
# Frame 195 Loss: 0.00203
# 1/1 [==============================] - 0s 21ms/step
# Frame 196 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 197 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 198 Loss: 0.00202
# 1/1 [==============================] - 0s 19ms/step
# Frame 199 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 200 Loss: 0.00202
# Processed 200 frames, found 0 anomalies so far.
# 1/1 [==============================] - 0s 18ms/step
# Frame 201 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 202 Loss: 0.00201
# 1/1 [==============================] - 0s 19ms/step
# Frame 203 Loss: 0.00201
# 1/1 [==============================] - 0s 16ms/step
# Frame 204 Loss: 0.00201
# 1/1 [==============================] - 0s 19ms/step
# Frame 205 Loss: 0.00201
# 1/1 [==============================] - 0s 20ms/step
# Frame 206 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 207 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 208 Loss: 0.00202
# 1/1 [==============================] - 0s 20ms/step
# Frame 209 Loss: 0.00203
# 1/1 [==============================] - 0s 16ms/step
# Frame 210 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 211 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 212 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 213 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 214 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 215 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 216 Loss: 0.00205
# 1/1 [==============================] - 0s 16ms/step
# Frame 217 Loss: 0.00205
# 1/1 [==============================] - 0s 17ms/step
# Frame 218 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 219 Loss: 0.00205
# 1/1 [==============================] - 0s 18ms/step
# Frame 220 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 221 Loss: 0.00204
# 1/1 [==============================] - 0s 19ms/step
# Frame 222 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 223 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 224 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 225 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 226 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 227 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 228 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 229 Loss: 0.00202
# 1/1 [==============================] - 0s 20ms/step
# Frame 230 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 231 Loss: 0.00202
# 1/1 [==============================] - 0s 17ms/step
# Frame 232 Loss: 0.00202
# 1/1 [==============================] - 0s 19ms/step
# Frame 233 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 234 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 235 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 236 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 237 Loss: 0.00204
# 1/1 [==============================] - 0s 19ms/step
# Frame 238 Loss: 0.00205
# 1/1 [==============================] - 0s 17ms/step
# Frame 239 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 240 Loss: 0.00204
# 1/1 [==============================] - 0s 20ms/step
# Frame 241 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 242 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 243 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 244 Loss: 0.00203
# 1/1 [==============================] - 0s 20ms/step
# Frame 245 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 246 Loss: 0.00203
# 1/1 [==============================] - 0s 19ms/step
# Frame 247 Loss: 0.00203
# 1/1 [==============================] - 0s 15ms/step
# Frame 248 Loss: 0.00203
# 1/1 [==============================] - 0s 18ms/step
# Frame 249 Loss: 0.00202
# 1/1 [==============================] - 0s 19ms/step
# Frame 250 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 251 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 252 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 253 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 254 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 255 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 256 Loss: 0.00200
# 1/1 [==============================] - 0s 19ms/step
# Frame 257 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 258 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 259 Loss: 0.00200
# 1/1 [==============================] - 0s 19ms/step
# Frame 260 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 261 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 262 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 263 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 264 Loss: 0.00202
# 1/1 [==============================] - 0s 18ms/step
# Frame 265 Loss: 0.00200
# 1/1 [==============================] - 0s 20ms/step
# Frame 266 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 267 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 268 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 269 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 270 Loss: 0.00201
# 1/1 [==============================] - 0s 18ms/step
# Frame 271 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 272 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 273 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 274 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 275 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 276 Loss: 0.00198
# 1/1 [==============================] - 0s 19ms/step
# Frame 277 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 278 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 279 Loss: 0.00199
# 1/1 [==============================] - 0s 21ms/step
# Frame 280 Loss: 0.00199
# 1/1 [==============================] - 0s 20ms/step
# Frame 281 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 282 Loss: 0.00199
# 1/1 [==============================] - 0s 19ms/step
# Frame 283 Loss: 0.00199
# 1/1 [==============================] - 0s 19ms/step
# Frame 284 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 285 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 286 Loss: 0.00199
# 1/1 [==============================] - 0s 19ms/step
# Frame 287 Loss: 0.00198
# 1/1 [==============================] - 0s 16ms/step
# Frame 288 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 289 Loss: 0.00198
# 1/1 [==============================] - 0s 19ms/step
# Frame 290 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 291 Loss: 0.00198
# 1/1 [==============================] - 0s 17ms/step
# Frame 292 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 293 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 294 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 295 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 296 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 297 Loss: 0.00195
# 1/1 [==============================] - 0s 20ms/step
# Frame 298 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 299 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 300 Loss: 0.00193
# Processed 300 frames, found 0 anomalies so far.
# 1/1 [==============================] - 0s 17ms/step
# Frame 301 Loss: 0.00192
# 1/1 [==============================] - 0s 17ms/step
# Frame 302 Loss: 0.00193
# 1/1 [==============================] - 0s 18ms/step
# Frame 303 Loss: 0.00194
# 1/1 [==============================] - 0s 17ms/step
# Frame 304 Loss: 0.00194
# 1/1 [==============================] - 0s 17ms/step
# Frame 305 Loss: 0.00194
# 1/1 [==============================] - 0s 19ms/step
# Frame 306 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 307 Loss: 0.00195
# 1/1 [==============================] - 0s 21ms/step
# Frame 308 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 309 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 310 Loss: 0.00195
# 1/1 [==============================] - 0s 20ms/step
# Frame 311 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 312 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 313 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 314 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 315 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 316 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 317 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 318 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 319 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 320 Loss: 0.00194
# 1/1 [==============================] - 0s 20ms/step
# Frame 321 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 322 Loss: 0.00193
# 1/1 [==============================] - 0s 17ms/step
# Frame 323 Loss: 0.00193
# 1/1 [==============================] - 0s 17ms/step
# Frame 324 Loss: 0.00194
# 1/1 [==============================] - 0s 17ms/step
# Frame 325 Loss: 0.00194
# 1/1 [==============================] - 0s 20ms/step
# Frame 326 Loss: 0.00193
# 1/1 [==============================] - 0s 19ms/step
# Frame 327 Loss: 0.00194
# 1/1 [==============================] - 0s 21ms/step
# Frame 328 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 329 Loss: 0.00194
# 1/1 [==============================] - 0s 16ms/step
# Frame 330 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 331 Loss: 0.00193
# 1/1 [==============================] - 0s 18ms/step
# Frame 332 Loss: 0.00193
# 1/1 [==============================] - 0s 20ms/step
# Frame 333 Loss: 0.00194
# 1/1 [==============================] - 0s 17ms/step
# Frame 334 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 335 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 336 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 337 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 338 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 339 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 340 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 341 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 342 Loss: 0.00194
# 1/1 [==============================] - 0s 21ms/step
# Frame 343 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 344 Loss: 0.00193
# 1/1 [==============================] - 0s 18ms/step
# Frame 345 Loss: 0.00192
# 1/1 [==============================] - 0s 22ms/step
# Frame 346 Loss: 0.00193
# 1/1 [==============================] - 0s 18ms/step
# Frame 347 Loss: 0.00193
# 1/1 [==============================] - 0s 19ms/step
# Frame 348 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 349 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 350 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 351 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 352 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 353 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 354 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 355 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 356 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 357 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 358 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 359 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 360 Loss: 0.00197
# 1/1 [==============================] - 0s 21ms/step
# Frame 361 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 362 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 363 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 364 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 365 Loss: 0.00196
# 1/1 [==============================] - 0s 21ms/step
# Frame 366 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 367 Loss: 0.00196
# 1/1 [==============================] - 0s 20ms/step
# Frame 368 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 369 Loss: 0.00194
# 1/1 [==============================] - 0s 17ms/step
# Frame 370 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 371 Loss: 0.00193
# 1/1 [==============================] - 0s 17ms/step
# Frame 372 Loss: 0.00193
# 1/1 [==============================] - 0s 18ms/step
# Frame 373 Loss: 0.00193
# 1/1 [==============================] - 0s 21ms/step
# Frame 374 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 375 Loss: 0.00194
# 1/1 [==============================] - 0s 19ms/step
# Frame 376 Loss: 0.00194
# 1/1 [==============================] - 0s 16ms/step
# Frame 377 Loss: 0.00194
# 1/1 [==============================] - 0s 19ms/step
# Frame 378 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 379 Loss: 0.00195
# 1/1 [==============================] - 0s 16ms/step
# Frame 380 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 381 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 382 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 383 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 384 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 385 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 386 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 387 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 388 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 389 Loss: 0.00196
# 1/1 [==============================] - 0s 20ms/step
# Frame 390 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 391 Loss: 0.00195
# 1/1 [==============================] - 0s 18ms/step
# Frame 392 Loss: 0.00194
# 1/1 [==============================] - 0s 17ms/step
# Frame 393 Loss: 0.00193
# 1/1 [==============================] - 0s 16ms/step
# Frame 394 Loss: 0.00193
# 1/1 [==============================] - 0s 19ms/step
# Frame 395 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 396 Loss: 0.00194
# 1/1 [==============================] - 0s 18ms/step
# Frame 397 Loss: 0.00195
# 1/1 [==============================] - 0s 19ms/step
# Frame 398 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 399 Loss: 0.00195
# 1/1 [==============================] - 0s 17ms/step
# Frame 400 Loss: 0.00196
# Processed 400 frames, found 0 anomalies so far.
# 1/1 [==============================] - 0s 18ms/step
# Frame 401 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 402 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 403 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 404 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 405 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 406 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 407 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 408 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 409 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 410 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 411 Loss: 0.00197
# 1/1 [==============================] - 0s 20ms/step
# Frame 412 Loss: 0.00197
# 1/1 [==============================] - 0s 19ms/step
# Frame 413 Loss: 0.00197
# 1/1 [==============================] - 0s 20ms/step
# Frame 414 Loss: 0.00197
# 1/1 [==============================] - 0s 20ms/step
# Frame 415 Loss: 0.00196
# 1/1 [==============================] - 0s 20ms/step
# Frame 416 Loss: 0.00196
# 1/1 [==============================] - 0s 19ms/step
# Frame 417 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 418 Loss: 0.00196
# 1/1 [==============================] - 0s 18ms/step
# Frame 419 Loss: 0.00196
# 1/1 [==============================] - 0s 21ms/step
# Frame 420 Loss: 0.00197
# 1/1 [==============================] - 0s 20ms/step
# Frame 421 Loss: 0.00198
# 1/1 [==============================] - 0s 20ms/step
# Frame 422 Loss: 0.00198
# 1/1 [==============================] - 0s 18ms/step
# Frame 423 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 424 Loss: 0.00199
# 1/1 [==============================] - 0s 19ms/step
# Frame 425 Loss: 0.00199
# 1/1 [==============================] - 0s 20ms/step
# Frame 426 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 427 Loss: 0.00200
# 1/1 [==============================] - 0s 15ms/step
# Frame 428 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 429 Loss: 0.00201
# 1/1 [==============================] - 0s 16ms/step
# Frame 430 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 431 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 432 Loss: 0.00200
# 1/1 [==============================] - 0s 18ms/step
# Frame 433 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 434 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 435 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 436 Loss: 0.00198
# 1/1 [==============================] - 0s 17ms/step
# Frame 437 Loss: 0.00198
# 1/1 [==============================] - 0s 16ms/step
# Frame 438 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 439 Loss: 0.00199
# 1/1 [==============================] - 0s 15ms/step
# Frame 440 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 441 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 442 Loss: 0.00199
# 1/1 [==============================] - 0s 20ms/step
# Frame 443 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 444 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 445 Loss: 0.00200
# 1/1 [==============================] - 0s 15ms/step
# Frame 446 Loss: 0.00201
# 1/1 [==============================] - 0s 16ms/step
# Frame 447 Loss: 0.00202
# 1/1 [==============================] - 0s 22ms/step
# Frame 448 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 449 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 450 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 451 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 452 Loss: 0.00200
# 1/1 [==============================] - 0s 15ms/step
# Frame 453 Loss: 0.00201
# 1/1 [==============================] - 0s 16ms/step
# Frame 454 Loss: 0.00201
# 1/1 [==============================] - 0s 17ms/step
# Frame 455 Loss: 0.00201
# 1/1 [==============================] - 0s 15ms/step
# Frame 456 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 457 Loss: 0.00200
# 1/1 [==============================] - 0s 15ms/step
# Frame 458 Loss: 0.00199
# 1/1 [==============================] - 0s 18ms/step
# Frame 459 Loss: 0.00198
# 1/1 [==============================] - 0s 16ms/step
# Frame 460 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 461 Loss: 0.00199
# 1/1 [==============================] - 0s 15ms/step
# Frame 462 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 463 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 464 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 465 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 466 Loss: 0.00198
# 1/1 [==============================] - 0s 17ms/step
# Frame 467 Loss: 0.00198
# 1/1 [==============================] - 0s 15ms/step
# Frame 468 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 469 Loss: 0.00200
# 1/1 [==============================] - 0s 15ms/step
# Frame 470 Loss: 0.00199
# 1/1 [==============================] - 0s 15ms/step
# Frame 471 Loss: 0.00200
# 1/1 [==============================] - 0s 15ms/step
# Frame 472 Loss: 0.00199
# 1/1 [==============================] - 0s 15ms/step
# Frame 473 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 474 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 475 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 476 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 477 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 478 Loss: 0.00200
# 1/1 [==============================] - 0s 15ms/step
# Frame 479 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 480 Loss: 0.00198
# 1/1 [==============================] - 0s 15ms/step
# Frame 481 Loss: 0.00197
# 1/1 [==============================] - 0s 18ms/step
# Frame 482 Loss: 0.00197
# 1/1 [==============================] - 0s 15ms/step
# Frame 483 Loss: 0.00198
# 1/1 [==============================] - 0s 16ms/step
# Frame 484 Loss: 0.00198
# 1/1 [==============================] - 0s 15ms/step
# Frame 485 Loss: 0.00198
# 1/1 [==============================] - 0s 16ms/step
# Frame 486 Loss: 0.00197
# 1/1 [==============================] - 0s 17ms/step
# Frame 487 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 488 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 489 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 490 Loss: 0.00200
# 1/1 [==============================] - 0s 16ms/step
# Frame 491 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 492 Loss: 0.00201
# 1/1 [==============================] - 0s 16ms/step
# Frame 493 Loss: 0.00202
# 1/1 [==============================] - 0s 16ms/step
# Frame 494 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 495 Loss: 0.00204
# 1/1 [==============================] - 0s 16ms/step
# Frame 496 Loss: 0.00203
# 1/1 [==============================] - 0s 17ms/step
# Frame 497 Loss: 0.00204
# 1/1 [==============================] - 0s 16ms/step
# Frame 498 Loss: 0.00204
# 1/1 [==============================] - 0s 14ms/step
# Frame 499 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 500 Loss: 0.00204
# Processed 500 frames, found 0 anomalies so far.
# 1/1 [==============================] - 0s 15ms/step
# Frame 501 Loss: 0.00205
# 1/1 [==============================] - 0s 18ms/step
# Frame 502 Loss: 0.00206
# 1/1 [==============================] - 0s 16ms/step
# Frame 503 Loss: 0.00207
# 1/1 [==============================] - 0s 17ms/step
# Frame 504 Loss: 0.00206
# 1/1 [==============================] - 0s 16ms/step
# Frame 505 Loss: 0.00205
# 1/1 [==============================] - 0s 16ms/step
# Frame 506 Loss: 0.00205
# 1/1 [==============================] - 0s 18ms/step
# Frame 507 Loss: 0.00205
# 1/1 [==============================] - 0s 15ms/step
# Frame 508 Loss: 0.00204
# 1/1 [==============================] - 0s 18ms/step
# Frame 509 Loss: 0.00205
# 1/1 [==============================] - 0s 16ms/step
# Frame 510 Loss: 0.00204
# 1/1 [==============================] - 0s 17ms/step
# Frame 511 Loss: 0.00203
# 1/1 [==============================] - 0s 16ms/step
# Frame 512 Loss: 0.00201
# 1/1 [==============================] - 0s 16ms/step
# Frame 513 Loss: 0.00200
# 1/1 [==============================] - 0s 17ms/step
# Frame 514 Loss: 0.00199
# 1/1 [==============================] - 0s 15ms/step
# Frame 515 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 516 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 517 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 518 Loss: 0.00199
# 1/1 [==============================] - 0s 16ms/step
# Frame 519 Loss: 0.00199
# 1/1 [==============================] - 0s 17ms/step
# Frame 520 Loss: 0.00198
# 1/1 [==============================] - 0s 16ms/step
# Frame 521 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 522 Loss: 0.00196
# 1/1 [==============================] - 0s 17ms/step
# Frame 523 Loss: 0.00194
# 1/1 [==============================] - 0s 16ms/step
# Frame 524 Loss: 0.00193
# 1/1 [==============================] - 0s 15ms/step
# Frame 525 Loss: 0.00193
# 1/1 [==============================] - 0s 16ms/step
# Frame 526 Loss: 0.00193
# 1/1 [==============================] - 0s 16ms/step
# Frame 527 Loss: 0.00193
# 1/1 [==============================] - 0s 16ms/step
# Frame 528 Loss: 0.00192
# 1/1 [==============================] - 0s 17ms/step
# Frame 529 Loss: 0.00190
# 1/1 [==============================] - 0s 17ms/step
# Frame 530 Loss: 0.00188
# 1/1 [==============================] - 0s 18ms/step
# Frame 531 Loss: 0.00188
# 1/1 [==============================] - 0s 17ms/step
# Frame 532 Loss: 0.00186
# 1/1 [==============================] - 0s 20ms/step
# Frame 533 Loss: 0.00185
# 1/1 [==============================] - 0s 16ms/step
# Frame 534 Loss: 0.00185
# 1/1 [==============================] - 0s 15ms/step
# Frame 535 Loss: 0.00185
# 1/1 [==============================] - 0s 17ms/step
# Frame 536 Loss: 0.00185
# 1/1 [==============================] - 0s 17ms/step
# Frame 537 Loss: 0.00185
# 1/1 [==============================] - 0s 16ms/step
# Frame 538 Loss: 0.00183
# 1/1 [==============================] - 0s 16ms/step
# Frame 539 Loss: 0.00181
# 1/1 [==============================] - 0s 15ms/step
# Frame 540 Loss: 0.00181
# 1/1 [==============================] - 0s 16ms/step
# Frame 541 Loss: 0.00179
# 1/1 [==============================] - 0s 17ms/step
# Frame 542 Loss: 0.00180
# 1/1 [==============================] - 0s 18ms/step
# Frame 543 Loss: 0.00182
# 1/1 [==============================] - 0s 19ms/step
# Frame 544 Loss: 0.00182
# 1/1 [==============================] - 0s 18ms/step
# Frame 545 Loss: 0.00183
# 1/1 [==============================] - 0s 20ms/step
# Frame 546 Loss: 0.00183
# 1/1 [==============================] - 0s 23ms/step
# Frame 547 Loss: 0.00184
# 1/1 [==============================] - 0s 20ms/step
# Frame 548 Loss: 0.00185
# 1/1 [==============================] - 0s 24ms/step
# Frame 549 Loss: 0.00185
# 1/1 [==============================] - 0s 20ms/step
# Frame 550 Loss: 0.00185
# 1/1 [==============================] - 0s 17ms/step
# Frame 551 Loss: 0.00185
# 1/1 [==============================] - 0s 16ms/step
# Frame 552 Loss: 0.00186
# 1/1 [==============================] - 0s 15ms/step
# Frame 553 Loss: 0.00184
# 1/1 [==============================] - 0s 16ms/step
# Frame 554 Loss: 0.00185
# 1/1 [==============================] - 0s 16ms/step
# Frame 555 Loss: 0.00181
# 1/1 [==============================] - 0s 16ms/step
# Frame 556 Loss: 0.00180
# 1/1 [==============================] - 0s 19ms/step
# Frame 557 Loss: 0.00180
# 1/1 [==============================] - 0s 36ms/step
# Frame 558 Loss: 0.00180
# 1/1 [==============================] - 0s 17ms/step
# Frame 559 Loss: 0.00181
# 1/1 [==============================] - 0s 16ms/step
# Frame 560 Loss: 0.00180
# 1/1 [==============================] - 0s 18ms/step
# Frame 561 Loss: 0.00179
# 1/1 [==============================] - 0s 20ms/step
# Frame 562 Loss: 0.00178
# 1/1 [==============================] - 0s 17ms/step
# Frame 563 Loss: 0.00177
# 1/1 [==============================] - 0s 17ms/step
# Frame 564 Loss: 0.00178
# 1/1 [==============================] - 0s 15ms/step
# Frame 565 Loss: 0.00178
# 1/1 [==============================] - 0s 16ms/step
# Frame 566 Loss: 0.00178
# 1/1 [==============================] - 0s 21ms/step
# Frame 567 Loss: 0.00177
# 1/1 [==============================] - 0s 16ms/step
# Frame 568 Loss: 0.00175
# 1/1 [==============================] - 0s 20ms/step
# Frame 569 Loss: 0.00174
# 1/1 [==============================] - 0s 18ms/step
# Frame 570 Loss: 0.00174
# 1/1 [==============================] - 0s 16ms/step
# Frame 571 Loss: 0.00173
# 1/1 [==============================] - 0s 17ms/step
# Frame 572 Loss: 0.00173
# 1/1 [==============================] - 0s 16ms/step
# Frame 573 Loss: 0.00174
# 1/1 [==============================] - 0s 18ms/step
# Frame 574 Loss: 0.00175
# 1/1 [==============================] - 0s 18ms/step
# Frame 575 Loss: 0.00175
# 1/1 [==============================] - 0s 16ms/step
# Frame 576 Loss: 0.00173
# 1/1 [==============================] - 0s 17ms/step
# Frame 577 Loss: 0.00173
# 1/1 [==============================] - 0s 17ms/step
# Frame 578 Loss: 0.00173
# 1/1 [==============================] - 0s 15ms/step
# Frame 579 Loss: 0.00174
# 1/1 [==============================] - 0s 16ms/step
# Frame 580 Loss: 0.00173
# 1/1 [==============================] - 0s 16ms/step
# Frame 581 Loss: 0.00172
# 1/1 [==============================] - 0s 16ms/step
# Frame 582 Loss: 0.00171
# 1/1 [==============================] - 0s 17ms/step
# Frame 583 Loss: 0.00171
# 1/1 [==============================] - 0s 15ms/step
# Frame 584 Loss: 0.00170
# 1/1 [==============================] - 0s 19ms/step
# Frame 585 Loss: 0.00170
# 1/1 [==============================] - 0s 17ms/step
# Frame 586 Loss: 0.00169
# 1/1 [==============================] - 0s 15ms/step
# Frame 587 Loss: 0.00168
# 1/1 [==============================] - 0s 18ms/step
# Frame 588 Loss: 0.00167
# 1/1 [==============================] - 0s 16ms/step
# Frame 589 Loss: 0.00167
# 1/1 [==============================] - 0s 16ms/step
# Frame 590 Loss: 0.00167
# 1/1 [==============================] - 0s 17ms/step
# Frame 591 Loss: 0.00168
# 1/1 [==============================] - 0s 16ms/step
# Frame 592 Loss: 0.00168
# 1/1 [==============================] - 0s 16ms/step
# Frame 593 Loss: 0.00167
# 1/1 [==============================] - 0s 16ms/step
# Frame 594 Loss: 0.00167
# 1/1 [==============================] - 0s 16ms/step
# Frame 595 Loss: 0.00166
# 1/1 [==============================] - 0s 16ms/step
# Frame 596 Loss: 0.00165
# 1/1 [==============================] - 0s 15ms/step
# Frame 597 Loss: 0.00165
# 1/1 [==============================] - 0s 17ms/step
# Frame 598 Loss: 0.00166
# 1/1 [==============================] - 0s 17ms/step
# Frame 599 Loss: 0.00166
# 1/1 [==============================] - 0s 15ms/step
# Frame 600 Loss: 0.00164
# Processed 600 frames, found 0 anomalies so far.
# 1/1 [==============================] - 0s 17ms/step
# Frame 601 Loss: 0.00161
# 1/1 [==============================] - 0s 16ms/step
# Frame 602 Loss: 0.00160
# 1/1 [==============================] - 0s 15ms/step
# Frame 603 Loss: 0.00159
# 1/1 [==============================] - 0s 17ms/step
# Frame 604 Loss: 0.00158
# 1/1 [==============================] - 0s 17ms/step
# Frame 605 Loss: 0.00158
# 1/1 [==============================] - 0s 16ms/step
# Frame 606 Loss: 0.00155
# 1/1 [==============================] - 0s 18ms/step
# Frame 607 Loss: 0.00154
# 1/1 [==============================] - 0s 15ms/step
# Frame 608 Loss: 0.00154
# 1/1 [==============================] - 0s 16ms/step
# Frame 609 Loss: 0.00155
# 1/1 [==============================] - 0s 16ms/step
# Frame 610 Loss: 0.00155
# 1/1 [==============================] - 0s 17ms/step
# Frame 611 Loss: 0.00154
# 1/1 [==============================] - 0s 18ms/step
# Frame 612 Loss: 0.00153
# 1/1 [==============================] - 0s 18ms/step
# Frame 613 Loss: 0.00154
# 1/1 [==============================] - 0s 17ms/step
# Frame 614 Loss: 0.00152
# 1/1 [==============================] - 0s 20ms/step
# Frame 615 Loss: 0.00152
# 1/1 [==============================] - 0s 17ms/step
# Frame 616 Loss: 0.00152
# 1/1 [==============================] - 0s 19ms/step
# Frame 617 Loss: 0.00152
# 1/1 [==============================] - 0s 16ms/step
# Frame 618 Loss: 0.00151
# 1/1 [==============================] - 0s 19ms/step
# Frame 619 Loss: 0.00152
# 1/1 [==============================] - 0s 18ms/step
# Frame 620 Loss: 0.00152
# 1/1 [==============================] - 0s 18ms/step
# Frame 621 Loss: 0.00151
# 1/1 [==============================] - 0s 18ms/step
# Frame 622 Loss: 0.00152
# 1/1 [==============================] - 0s 18ms/step
# Frame 623 Loss: 0.00151
# 1/1 [==============================] - 0s 18ms/step
# Frame 624 Loss: 0.00150
# 1/1 [==============================] - 0s 18ms/step
# Frame 625 Loss: 0.00150
# 1/1 [==============================] - 0s 17ms/step
# Frame 626 Loss: 0.00148
# 1/1 [==============================] - 0s 17ms/step
# Frame 627 Loss: 0.00147
# 1/1 [==============================] - 0s 19ms/step
# Frame 628 Loss: 0.00146
# ...
# 1/1 [==============================] - 0s 37ms/step
# Frame 4260 Loss: 0.00211
# 1/1 [==============================] - 0s 36ms/step
# Frame 4261 Loss: 0.00210
# 1/1 [==============================] - 0s 32ms/step
# Frame 4262 Loss: 0.00210
# 1/1 [==============================] - 0s 33ms/step
# Frame 4263 Loss: 0.00209
# 1/1 [==============================] - 0s 32ms/step
# Frame 4264 Loss: 0.00206
# 1/1 [==============================] - 0s 33ms/step
# Frame 4265 Loss: 0.00206
# 1/1 [==============================] - 0s 31ms/step
# Frame 4266 Loss: 0.00207
# 1/1 [==============================] - 0s 38ms/step
# Frame 4267 Loss: 0.00206
# 1/1 [==============================] - 0s 35ms/step
# Frame 4268 Loss: 0.00204
# 1/1 [==============================] - 0s 36ms/step
# Frame 4269 Loss: 0.00204
# 1/1 [==============================] - 0s 29ms/step
# Frame 4270 Loss: 0.00204
# 1/1 [==============================] - 0s 38ms/step
# Frame 4271 Loss: 0.00203
# 1/1 [==============================] - 0s 39ms/step
# Frame 4272 Loss: 0.00204
# 1/1 [==============================] - 0s 33ms/step
# Frame 4273 Loss: 0.00204
# 1/1 [==============================] - 0s 32ms/step
# Frame 4274 Loss: 0.00203
# 1/1 [==============================] - 0s 33ms/step
# Frame 4275 Loss: 0.00201
# 1/1 [==============================] - 0s 31ms/step
# Frame 4276 Loss: 0.00199
# 1/1 [==============================] - 0s 29ms/step
# Frame 4277 Loss: 0.00200
# 1/1 [==============================] - 0s 32ms/step
# Frame 4278 Loss: 0.00200
# 1/1 [==============================] - 0s 34ms/step
# Frame 4279 Loss: 0.00200
# 1/1 [==============================] - 0s 31ms/step
# Frame 4280 Loss: 0.00198
# 1/1 [==============================] - 0s 33ms/step
# Frame 4281 Loss: 0.00199
# 1/1 [==============================] - 0s 32ms/step
# Frame 4282 Loss: 0.00200
# 1/1 [==============================] - 0s 28ms/step
# Frame 4283 Loss: 0.00200
# 1/1 [==============================] - 0s 32ms/step
# Frame 4284 Loss: 0.00199
# 1/1 [==============================] - 0s 35ms/step
# Frame 4285 Loss: 0.00199
# 1/1 [==============================] - 0s 33ms/step
# Frame 4286 Loss: 0.00199
# 1/1 [==============================] - 0s 33ms/step
# Frame 4287 Loss: 0.00199
# 1/1 [==============================] - 0s 34ms/step
# Frame 4288 Loss: 0.00199
# 1/1 [==============================] - 0s 31ms/step
# Frame 4289 Loss: 0.00200
# 1/1 [==============================] - 0s 33ms/step
# Frame 4290 Loss: 0.00200
# 1/1 [==============================] - 0s 35ms/step
# Frame 4291 Loss: 0.00201
# 1/1 [==============================] - 0s 33ms/step
# Frame 4292 Loss: 0.00201
# 1/1 [==============================] - 0s 34ms/step
# Frame 4293 Loss: 0.00200
# 1/1 [==============================] - 0s 33ms/step
# Frame 4294 Loss: 0.00201
# 1/1 [==============================] - 0s 29ms/step
# Frame 4295 Loss: 0.00201
# 1/1 [==============================] - 0s 36ms/step
# Frame 4296 Loss: 0.00200
# 1/1 [==============================] - 0s 30ms/step
# Frame 4297 Loss: 0.00200
# 1/1 [==============================] - 0s 34ms/step
# Frame 4298 Loss: 0.00199
# 1/1 [==============================] - 0s 44ms/step
# Frame 4299 Loss: 0.00197
# 1/1 [==============================] - 0s 32ms/step
# Frame 4300 Loss: 0.00198
# Processed 4300 frames, found 836 anomalies so far.
# 1/1 [==============================] - 0s 31ms/step
# Frame 4301 Loss: 0.00199
# 1/1 [==============================] - 0s 34ms/step
# Frame 4302 Loss: 0.00200
# 1/1 [==============================] - 0s 40ms/step
# Frame 4303 Loss: 0.00200
# 1/1 [==============================] - 0s 34ms/step
# Frame 4304 Loss: 0.00199
# 1/1 [==============================] - 0s 36ms/step
# Frame 4305 Loss: 0.00200
# 1/1 [==============================] - 0s 29ms/step
# Frame 4306 Loss: 0.00200
# 1/1 [==============================] - 0s 32ms/step
# Frame 4307 Loss: 0.00200
# 1/1 [==============================] - 0s 32ms/step
# Frame 4308 Loss: 0.00200
# 1/1 [==============================] - 0s 30ms/step
# Frame 4309 Loss: 0.00198
# 1/1 [==============================] - 0s 35ms/step
# Frame 4310 Loss: 0.00199
# 1/1 [==============================] - 0s 36ms/step
# Frame 4311 Loss: 0.00200
# 1/1 [==============================] - 0s 34ms/step
# Frame 4312 Loss: 0.00200
# 1/1 [==============================] - 0s 32ms/step
# Frame 4313 Loss: 0.00199
# 1/1 [==============================] - 0s 32ms/step
# Frame 4314 Loss: 0.00199
# 1/1 [==============================] - 0s 39ms/step
# Frame 4315 Loss: 0.00199
# 1/1 [==============================] - 0s 32ms/step
# Frame 4316 Loss: 0.00199
# 1/1 [==============================] - 0s 33ms/step
# Frame 4317 Loss: 0.00198
# 1/1 [==============================] - 0s 33ms/step
# Frame 4318 Loss: 0.00199
# 1/1 [==============================] - 0s 36ms/step
# Frame 4319 Loss: 0.00197
# 1/1 [==============================] - 0s 33ms/step
# Frame 4320 Loss: 0.00197
# 1/1 [==============================] - 0s 29ms/step
# Frame 4321 Loss: 0.00194
# 1/1 [==============================] - 0s 30ms/step
# Frame 4322 Loss: 0.00194
# 1/1 [==============================] - 0s 35ms/step
# Frame 4323 Loss: 0.00193
# 1/1 [==============================] - 0s 33ms/step
# Frame 4324 Loss: 0.00193
# 1/1 [==============================] - 0s 35ms/step
# Frame 4325 Loss: 0.00192
# 1/1 [==============================] - 0s 28ms/step
# Frame 4326 Loss: 0.00193
# 1/1 [==============================] - 0s 36ms/step
# Frame 4327 Loss: 0.00194
# 1/1 [==============================] - 0s 28ms/step
# Frame 4328 Loss: 0.00196
# 1/1 [==============================] - 0s 30ms/step
# Frame 4329 Loss: 0.00197
# 1/1 [==============================] - 0s 31ms/step
# Frame 4330 Loss: 0.00198
# 1/1 [==============================] - 0s 40ms/step
# Frame 4331 Loss: 0.00199
# 1/1 [==============================] - 0s 42ms/step
# Frame 4332 Loss: 0.00199
# 1/1 [==============================] - 0s 33ms/step
# Frame 4333 Loss: 0.00201
# 1/1 [==============================] - 0s 37ms/step
# Frame 4334 Loss: 0.00201
# 1/1 [==============================] - 0s 32ms/step
# Frame 4335 Loss: 0.00204
# 1/1 [==============================] - 0s 35ms/step
# Frame 4336 Loss: 0.00205
# 1/1 [==============================] - 0s 32ms/step
# Frame 4337 Loss: 0.00204
# 1/1 [==============================] - 0s 33ms/step
# Frame 4338 Loss: 0.00204
# 1/1 [==============================] - 0s 35ms/step
# Frame 4339 Loss: 0.00202
# 1/1 [==============================] - 0s 34ms/step
# Frame 4340 Loss: 0.00200
# 1/1 [==============================] - 0s 33ms/step
# Frame 4341 Loss: 0.00200
# 1/1 [==============================] - 0s 31ms/step
# Frame 4342 Loss: 0.00200
# 1/1 [==============================] - 0s 32ms/step
# Frame 4343 Loss: 0.00200
# 1/1 [==============================] - 0s 35ms/step
# Frame 4344 Loss: 0.00200
# 1/1 [==============================] - 0s 31ms/step
# Frame 4345 Loss: 0.00197
# 1/1 [==============================] - 0s 36ms/step
# Frame 4346 Loss: 0.00195
# 1/1 [==============================] - 0s 36ms/step
# Frame 4347 Loss: 0.00193
# 1/1 [==============================] - 0s 30ms/step
# Frame 4348 Loss: 0.00193
# 1/1 [==============================] - 0s 35ms/step
# Frame 4349 Loss: 0.00192
# 1/1 [==============================] - 0s 40ms/step
# Frame 4350 Loss: 0.00193
# 1/1 [==============================] - 0s 33ms/step
# Frame 4351 Loss: 0.00191
# 1/1 [==============================] - 0s 31ms/step
# Frame 4352 Loss: 0.00190
# 1/1 [==============================] - 0s 41ms/step
# Frame 4353 Loss: 0.00191
# 1/1 [==============================] - 0s 33ms/step
# Frame 4354 Loss: 0.00192
# 1/1 [==============================] - 0s 33ms/step
# Frame 4355 Loss: 0.00192
# 1/1 [==============================] - 0s 29ms/step
# Frame 4356 Loss: 0.00193
# 1/1 [==============================] - 0s 35ms/step
# Frame 4357 Loss: 0.00194
# 1/1 [==============================] - 0s 25ms/step
# Frame 4358 Loss: 0.00195
# 1/1 [==============================] - 0s 40ms/step
# Frame 4359 Loss: 0.00199
# 1/1 [==============================] - 0s 29ms/step
# Frame 4360 Loss: 0.00200
# 1/1 [==============================] - 0s 37ms/step
# Frame 4361 Loss: 0.00200
# 1/1 [==============================] - 0s 33ms/step
# Frame 4362 Loss: 0.00201
# 1/1 [==============================] - 0s 40ms/step
# Frame 4363 Loss: 0.00201
# 1/1 [==============================] - 0s 32ms/step
# Frame 4364 Loss: 0.00200
# 1/1 [==============================] - 0s 34ms/step
# Frame 4365 Loss: 0.00200
# 1/1 [==============================] - 0s 35ms/step
# Frame 4366 Loss: 0.00201
# 1/1 [==============================] - 0s 48ms/step
# Frame 4367 Loss: 0.00199
# 1/1 [==============================] - 0s 33ms/step
# Frame 4368 Loss: 0.00198
# 1/1 [==============================] - 0s 36ms/step
# Frame 4369 Loss: 0.00193
# 1/1 [==============================] - 0s 33ms/step
# Frame 4370 Loss: 0.00192
# 1/1 [==============================] - 0s 37ms/step
# Frame 4371 Loss: 0.00191
# 1/1 [==============================] - 0s 35ms/step
# Frame 4372 Loss: 0.00189
# 1/1 [==============================] - 0s 31ms/step
# Frame 4373 Loss: 0.00188
# 1/1 [==============================] - 0s 28ms/step
# Frame 4374 Loss: 0.00188
# 1/1 [==============================] - 0s 35ms/step
# Frame 4375 Loss: 0.00188
# 1/1 [==============================] - 0s 32ms/step
# Frame 4376 Loss: 0.00188
# 1/1 [==============================] - 0s 32ms/step
# Frame 4377 Loss: 0.00188
# 1/1 [==============================] - 0s 35ms/step
# Frame 4378 Loss: 0.00188
# 1/1 [==============================] - 0s 33ms/step
# Frame 4379 Loss: 0.00190
# 1/1 [==============================] - 0s 34ms/step
# Frame 4380 Loss: 0.00189
# 1/1 [==============================] - 0s 33ms/step
# Frame 4381 Loss: 0.00190
# 1/1 [==============================] - 0s 34ms/step
# Frame 4382 Loss: 0.00190
# 1/1 [==============================] - 0s 40ms/step
# Frame 4383 Loss: 0.00190
# 1/1 [==============================] - 0s 33ms/step
# Frame 4384 Loss: 0.00189
# 1/1 [==============================] - 0s 35ms/step
# Frame 4385 Loss: 0.00190
# 1/1 [==============================] - 0s 33ms/step
# Frame 4386 Loss: 0.00190
# 1/1 [==============================] - 0s 33ms/step
# Frame 4387 Loss: 0.00192
# 1/1 [==============================] - 0s 36ms/step
# Frame 4388 Loss: 0.00193
# 1/1 [==============================] - 0s 32ms/step
# Frame 4389 Loss: 0.00195
# 1/1 [==============================] - 0s 36ms/step
# Frame 4390 Loss: 0.00195
# 1/1 [==============================] - 0s 38ms/step
# Frame 4391 Loss: 0.00195
# 1/1 [==============================] - 0s 38ms/step
# Frame 4392 Loss: 0.00194
# 1/1 [==============================] - 0s 37ms/step
# Frame 4393 Loss: 0.00190
# 1/1 [==============================] - 0s 31ms/step
# Frame 4394 Loss: 0.00190
# 1/1 [==============================] - 0s 35ms/step
# Frame 4395 Loss: 0.00189
# 1/1 [==============================] - 0s 31ms/step
# Frame 4396 Loss: 0.00188
# 1/1 [==============================] - 0s 32ms/step
# Frame 4397 Loss: 0.00188
# 1/1 [==============================] - 0s 33ms/step
# Frame 4398 Loss: 0.00187
# 1/1 [==============================] - 0s 35ms/step
# Frame 4399 Loss: 0.00187
# 1/1 [==============================] - 0s 35ms/step
# Frame 4400 Loss: 0.00187
# Processed 4400 frames, found 836 anomalies so far.
# 1/1 [==============================] - 0s 31ms/step
# Frame 4401 Loss: 0.00188
# 1/1 [==============================] - 0s 30ms/step
# Frame 4402 Loss: 0.00189
# 1/1 [==============================] - 0s 32ms/step
# Frame 4403 Loss: 0.00191
# 1/1 [==============================] - 0s 37ms/step
# Frame 4404 Loss: 0.00190
# 1/1 [==============================] - 0s 30ms/step
# Frame 4405 Loss: 0.00189
# 1/1 [==============================] - 0s 29ms/step
# Frame 4406 Loss: 0.00190
# 1/1 [==============================] - 0s 38ms/step
# Frame 4407 Loss: 0.00190
# 1/1 [==============================] - 0s 41ms/step
# Frame 4408 Loss: 0.00189
# 1/1 [==============================] - 0s 33ms/step
# Frame 4409 Loss: 0.00188
# 1/1 [==============================] - 0s 34ms/step
# Frame 4410 Loss: 0.00189
# 1/1 [==============================] - 0s 39ms/step
# Frame 4411 Loss: 0.00189
# 1/1 [==============================] - 0s 21ms/step
# Frame 4412 Loss: 0.00188
# 1/1 [==============================] - 0s 16ms/step
# Frame 4413 Loss: 0.00190
# 1/1 [==============================] - 0s 18ms/step
# Frame 4414 Loss: 0.00190
# 1/1 [==============================] - 0s 17ms/step
# Frame 4415 Loss: 0.00192
# 1/1 [==============================] - 0s 24ms/step
# Frame 4416 Loss: 0.00189
# 1/1 [==============================] - 0s 22ms/step
# Frame 4417 Loss: 0.00193
# 1/1 [==============================] - 0s 19ms/step
# Frame 4418 Loss: 0.00192
# 1/1 [==============================] - 0s 16ms/step
# Frame 4419 Loss: 0.00192
# 1/1 [==============================] - 0s 18ms/step
# Frame 4420 Loss: 0.00192
# 1/1 [==============================] - 0s 19ms/step
# Frame 4421 Loss: 0.00191
# 1/1 [==============================] - 0s 22ms/step
# Frame 4422 Loss: 0.00191
# 1/1 [==============================] - 0s 20ms/step
# Frame 4423 Loss: 0.00190
# 1/1 [==============================] - 0s 20ms/step
# Frame 4424 Loss: 0.00189
# 1/1 [==============================] - 0s 17ms/step
# Frame 4425 Loss: 0.00190
# 1/1 [==============================] - 0s 16ms/step
# Frame 4426 Loss: 0.00190
# 1/1 [==============================] - 0s 18ms/step
# Frame 4427 Loss: 0.00191
# 1/1 [==============================] - 0s 21ms/step
# Frame 4428 Loss: 0.00190
# 1/1 [==============================] - 0s 18ms/step
# Frame 4429 Loss: 0.00191
# 1/1 [==============================] - 0s 17ms/step
# Frame 4430 Loss: 0.00192
# 1/1 [==============================] - 0s 21ms/step
# Frame 4431 Loss: 0.00191
# 1/1 [==============================] - 0s 18ms/step
# Frame 4432 Loss: 0.00189
# 1/1 [==============================] - 0s 15ms/step
# Frame 4433 Loss: 0.00187
# 1/1 [==============================] - 0s 17ms/step
# Frame 4434 Loss: 0.00187
# 1/1 [==============================] - 0s 20ms/step
# Frame 4435 Loss: 0.00189
# 1/1 [==============================] - 0s 15ms/step
# Frame 4436 Loss: 0.00187
# 1/1 [==============================] - 0s 16ms/step
# Frame 4437 Loss: 0.00188
# 1/1 [==============================] - 0s 17ms/step
# Frame 4438 Loss: 0.00189
# 1/1 [==============================] - 0s 19ms/step
# Frame 4439 Loss: 0.00190
# 1/1 [==============================] - 0s 17ms/step
# Frame 4440 Loss: 0.00191
# 1/1 [==============================] - 0s 18ms/step
# Frame 4441 Loss: 0.00187
# 1/1 [==============================] - 0s 17ms/step
# Frame 4442 Loss: 0.00188
# 1/1 [==============================] - 0s 18ms/step
# Frame 4443 Loss: 0.00191
# 1/1 [==============================] - 0s 19ms/step
# Frame 4444 Loss: 0.00191
# 1/1 [==============================] - 0s 17ms/step
# Frame 4445 Loss: 0.00189
# 1/1 [==============================] - 0s 18ms/step
# Frame 4446 Loss: 0.00189
# 1/1 [==============================] - 0s 19ms/step
# Frame 4447 Loss: 0.00121
# 1/1 [==============================] - 0s 16ms/step
# Frame 4448 Loss: 0.00121
# 1/1 [==============================] - 0s 19ms/step
# Frame 4449 Loss: 0.00123
# 1/1 [==============================] - 0s 17ms/step
# Frame 4450 Loss: 0.00123
# 1/1 [==============================] - 0s 18ms/step
# Frame 4451 Loss: 0.00124
# 1/1 [==============================] - 0s 17ms/step
# Frame 4452 Loss: 0.00125
# 1/1 [==============================] - 0s 16ms/step
# Frame 4453 Loss: 0.00126
# 1/1 [==============================] - 0s 18ms/step
# Frame 4454 Loss: 0.00126
# 1/1 [==============================] - 0s 16ms/step
# Frame 4455 Loss: 0.00126
# 1/1 [==============================] - 0s 17ms/step
# Frame 4456 Loss: 0.00128
# 1/1 [==============================] - 0s 16ms/step
# Frame 4457 Loss: 0.00129
# 1/1 [==============================] - 0s 20ms/step
# Frame 4458 Loss: 0.00128
# 1/1 [==============================] - 0s 18ms/step
# Frame 4459 Loss: 0.00129
# 1/1 [==============================] - 0s 17ms/step
# Frame 4460 Loss: 0.00129
# 1/1 [==============================] - 0s 18ms/step
# Frame 4461 Loss: 0.00128
# 1/1 [==============================] - 0s 23ms/step
# Frame 4462 Loss: 0.00125
# 1/1 [==============================] - 0s 16ms/step
# Frame 4463 Loss: 0.00123
#
# Processing complete!
# Total frames processed: 4463
# Total anomalies detected: 836
# Anomaly rate: 18.73%
#
# Creating loss graph...
# Loss graph saved: output_video\loss_graph.png

# %% [markdown]
# ## Output with loss realtime graph analysis

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import imutils
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# Adjusted threshold for overall frame anomaly detection
ANOMALY_THRESHOLD = 0.00080
ANOMALY_REGION_PIXEL_THRESHOLD = 0.0030

# Define model and video paths
model_dir = "../models/oil_Drone_model_e50_b4.h5"
#video_path = "D:\\Research Dataset\\OIL gas\\testing\\Anomaly nan 1.mp4"
video_path = "D:\\Research Dataset\\Drone anomaly New\\Testing\\Drone anomaly new.mp4" # Path to the video file
output_video_path = "loss_graph_video.mp4" # Path to save the plot video
plot_frame_dir = "plot_frames" # Directory to save individual plot frames

# Create output directories if they don't exist
if not os.path.exists("output_frames"):
    os.makedirs("output_frames")
if not os.path.exists("reconstructed_frames"):
    os.makedirs("reconstructed_frames")
if not os.path.exists("anomaly_maps"):
    os.makedirs("anomaly_maps")
if not os.path.exists(plot_frame_dir):
    os.makedirs(plot_frame_dir)

# Lists to store frame loss data and frame numbers
frame_losses = []
frame_numbers = []
frame_count_processed = 0
anomaly_count = 0


# Function to calculate Mean Squared Error (MSE) loss
def mean_squared_loss(x1, x2):
    x1_np = x1.numpy() if tf.is_tensor(x1) else x1
    x2_np = x2.numpy() if tf.is_tensor(x2) else x2
    difference = x1_np.flatten() - x2_np.flatten()
    sq_difference = difference ** 2
    mse = np.mean(sq_difference)
    return mse

# Custom loss function for Keras model loading
def combined_loss(y_true, y_pred):
    mse_loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
    return mse_loss

# Function to preprocess frames for the model
def preprocess_frame_for_new_model(frame):
    """ Transformation:
    Subtracting 0.5 shifts the range:

    0 becomes -0.5

    1 becomes 0.5

    The new range is [-0.5, 0.5].

    Multiplying by 2 scales the range:

    -0.5 becomes -1

    0.5 becomes 1

    The final range is [-1, 1].

    tanh or certain loss functions, perform better with input data scaled to the range [-1, 1].

"""
    frame_resized = cv2.resize(frame, (232, 232), interpolation=cv2.INTER_AREA)
    gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
    gray = gray.astype(np.float32) / 255.0 # After converting the frame to grayscale and dividing by 255.0, the pixel values are in the range of [0, 1].
    gray = (gray - 0.5) * 2
    return gray

# Load the pre-trained Keras model
custom_objects = {'combined_loss': combined_loss}
try:
    model = load_model(model_dir, custom_objects=custom_objects)
    print("Frame-by-frame model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Please ensure 'model.h5' is in the '../models/' directory and the custom loss function is defined.")
    exit()

# Open the video file
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video file at {video_path}")
    exit()
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total frames in video: {length}")


# Initialize the plot
fig, ax = plt.subplots()
line, = ax.plot(frame_numbers, frame_losses)
ax.set_xlabel('Frame Number')
ax.set_ylabel('Mean Squared Error (MSE)')
ax.set_title('Real-time Reconstruction Loss')
ax.grid(True)

# Set initial fixed x-axis limits
initial_x_limit = length
ax.set_xlim(0, initial_x_limit)
# Set initial fixed y-axis limits from 0 to 2
ax.set_ylim(0, 0.0060) ## I may need to adjust it

# Main loop for frame processing
while True:
    ret, raw_frame = cap.read()
    if not ret:
        print("End of video.")
        break

    frame_count_processed += 1
    original_frame_color = imutils.resize(raw_frame, width=700, height=600)
    processed_frame = preprocess_frame_for_new_model(raw_frame)
    model_input_frame = np.expand_dims(np.expand_dims(processed_frame, axis=0), axis=-1)
    output = model.predict(model_input_frame)
    reconstructed_frame_2d = output[0, :, :, 0]
    reconstructed_frame_display = ((reconstructed_frame_2d + 1) / 2 * 255).astype(np.uint8)
    reconstructed_frame_display = cv2.resize(
        reconstructed_frame_display, (original_frame_color.shape[1], original_frame_color.shape[0])
    )
    cv2.imwrite(f"reconstructed_frames/frame_{frame_count_processed:05d}_reconstructed.jpg", reconstructed_frame_display)

    loss = mean_squared_loss(model_input_frame, output)
    loss_display = f"{loss:.5f}"
    print(f"Frame {frame_count_processed} Loss: {loss_display}")

    frame_losses.append(loss)
    frame_numbers.append(frame_count_processed)

    # Update the plot data
    line.set_xdata(frame_numbers)
    line.set_ydata(frame_losses)

    # Dynamically adjust x-axis limits for scrolling effect
    if frame_count_processed > initial_x_limit:
        ax.set_xlim(frame_count_processed - initial_x_limit, frame_count_processed)
    else:
        ax.set_xlim(0, initial_x_limit)

    # Redraw the canvas and save the plot frame
    fig.canvas.draw()
    plot_frame_filename = os.path.join(plot_frame_dir, f"plot_frame_{frame_count_processed:05d}.png")
    fig.savefig(plot_frame_filename) # Save the plot as an image

    display_frame = original_frame_color.copy()
    status_text = f"Normal" #: {loss_display}
    color = (0, 255, 0)

    if loss > ANOMALY_THRESHOLD:
        status_text = f"Anomaly" #: {loss_display}
        color = (0, 0, 255)
        anomaly_count += 1

        # --- Anomaly Localization with Overlay ---
        squared_diff_map = (processed_frame - reconstructed_frame_2d)**2 #Highlights regions where the model's reconstruction significantly differs from the input, potentially indicating anomalies.
        # Normalize the squared difference map to [0, 255] for thresholding
        scaled_diff_map = (squared_diff_map * 255).astype(np.uint8) # Scales the values of squared_diff_map from its normalized range (e.g., [0, 1]) to a pixel intensity range of [0, 255].
        _, binary_error_mask = cv2.threshold(
            scaled_diff_map,
            int(ANOMALY_REGION_PIXEL_THRESHOLD * 255),
            255,
            cv2.THRESH_BINARY
        ) #  image thresholding, a technique that converts grayscale images into binary images by setting pixel values based on a threshold
        binary_error_mask_resized = cv2.resize(
            binary_error_mask, (original_frame_color.shape[1], original_frame_color.shape[0]),
            interpolation=cv2.INTER_NEAREST
        )
        contours, _ = cv2.findContours(
            binary_error_mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
        )
        for contour in contours:              
            if cv2.contourArea(contour) > 50: #In this code, 50 is the minimum contour area threshold . Lower values (like 10-30): Will detect smaller objects but may include more noise
                x, y, w, h = cv2.boundingRect(contour)                                                 #Higher values (like 100-500): Will only detect larger, more significant objects but might miss smaller relevant features
                # overlay = display_frame.copy()
                # cv2.rectangle(overlay, (x, y), (x + w, y + h), (0, 0, 255), -1)
                # alpha = 0.50
                # display_frame = cv2.addWeighted(overlay, alpha, display_frame, 1 - alpha, 0)
                if w > 30 and h > 30:  # Adjust these values as needed
                    cv2.rectangle(display_frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
                #cv2.rectangle(display_frame, (x, y), (x + w, y + h), (0, 0, 255), 2)

    cv2.putText(display_frame, status_text, (100, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.8, color, 2)
    cv2.imwrite(f"output_frames/frame_{frame_count_processed:05d}.jpg", display_frame)
    cv2.imshow("Anomaly Detection", display_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting video processing.")
        break

# Release video capture and destroy all OpenCV windows
cap.release()
cv2.destroyAllWindows()
plt.close(fig) # Close the Matplotlib figure

print(f"\nProcessing complete!")
print(f"Total frames processed: {frame_count_processed}")
print(f"Total anomalies detected: {anomaly_count}")
if frame_count_processed > 0:
    anomaly_rate = (anomaly_count / frame_count_processed * 100)
    print(f"Anomaly rate: {anomaly_rate:.2f}%")
else:
    print("No frames were processed, cannot calculate anomaly rate.")

# Save the final loss data to a CSV file
loss_data = np.array([frame_numbers, frame_losses]).T
np.savetxt("loss_data_final.csv", loss_data, delimiter=",", header="frame_number,loss", comments="")
print("Final loss information saved to loss_data_final.csv")
# Out:
# Frame-by-frame model loaded successfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 90
#      87     exit()
#      89 # Open the video file
# ---> 90 cap = cv2.VideoCapture(video_path)
#      91 if not cap.isOpened():
#      92     print(f"Error: Could not open video file at {video_path}")
#
# KeyboardInterrupt:
